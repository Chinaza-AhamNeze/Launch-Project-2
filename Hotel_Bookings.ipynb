# %%
pip install pymongo
# Out:
# Requirement already satisfied: pymongo in c:\users\samue\anaconda3\lib\site-packages (4.13.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\samue\anaconda3\lib\site-packages (from pymongo) (2.7.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymongo
from pymongo import MongoClient
import pandas as pd

# %%
client = MongoClient('localhost', 27017)

# %%
client
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
db = client.HotelData

# %%
collection = db.Rooms

# %%
Rooms = pd.read_excel('C:\\Users\\samue\\Downloads\\SQL project data\\Rooms.xlsx')
Rooms.head(3)
# Out:
#    room_id  number    view_type  capacity  room_type    availability  \
# 0        1     101     Poolside         4  Penthouse  Out of Service
# 1        2     102  Street View         4  Penthouse       Available
# 2        3     103     Poolside         2     Double       Available
#
#   last_maintenance_date accessibility_accomodation
# 0            2025-04-06                        NaN
# 1            2025-01-13                        NaN
# 2            2025-04-18                        NaN

# %%
rooms_dict = Rooms.to_dict('records')
rooms_dict
# Out:
# [{'room_id': 1,
#   'number': 101,
#   'view_type': 'Poolside',
#   'capacity': 4,
#   'room_type': 'Penthouse',
#   'availability': 'Out of Service',
#   'last_maintenance_date': Timestamp('2025-04-06 00:00:00'),
#   'accessibility_accomodation': nan},
#  {'room_id': 2,
#   'number': 102,
#   'view_type': 'Street View',
#   'capacity': 4,
#   'room_type': 'Penthouse',
#   'availability': 'Available',
#   'last_maintenance_date': Timestamp('2025-01-13 00:00:00'),
#   'accessibility_accomodation': nan},
#  {'room_id': 3,
#   'number': 103,
#   'view_type': 'Poolside',
#   'capacity': 2,
#   'room_type': 'Double',
#   'availability': 'Available',
#   'last_maintenance_date': Timestamp('2025-04-18 00:00:00'),
#   'accessibility_accomodation': nan},
#  {'room_id': 4,
#   'number': 104,
#   'view_type': 'Street View',
#   'capacity': 1,
#   'room_type': 'Single',
#   'availability': 'Out of Service',
#   'last_maintenance_date': Timestamp('2025-03-07 00:00:00'),
#   'accessibility_accomodation': 'Hearing Impairment Support'},
#  {'room_id': 5,
#   'number': 105,
#   'view_type': 'Street View',
#   'capacity': 1,
#   'room_type': 'Single',
#   'availability': 'Occupied',
#   'last_maintenance_date': Timestamp('2025-01-10 00:00:00'),
#   'accessibility_accomodation': 'Wheelchair Access'},
#  {'room_id': 6,
#   'number': 106,
#   'view_type': 'Ocean View',
#   'capacity': 2,
#   'room_type': 'Double',
#   'availability': 'Available',
#   'last_maintenance_date': Timestamp('2025-01-20 00:00:00'),
#   'accessibility_accomodation': 'Hearing Impairment Support'},
#  {'room_id': 7,
#   'number': 107,
#   'view_type': 'Ocean View',
#   'capacity': 2,
#   'room_type': 'Double',
#   'availability': 'Occupied',
#   'last_maintenance_date': Timestamp('2025-01-23 00:00:00'),
#   'accessibility_accomodation': 'Wheelchair Access'},
#  {'room_id': 8,
#   'number': 108,
#   'view_type': 'Ocean View',
#   'capacity': 2,
#   'room_type': 'Double',
#   'availability': 'Available',
#   'last_maintenance_date': Timestamp('2025-03-18 00:00:00'),
#   'accessibility_accomodation': 'Wheelchair Access'},
#  {'room_id': 9,
#   'number': 109,
#   'view_type': 'Street View',
#   'capacity': 1,
#   'room_type': 'Single',
#   'availability': 'Occupied',
#   'last_maintenance_date': Timestamp('2025-03-22 00:00:00'),
#   'accessibility_accomodation': nan},
#  {'room_id': 10,
#   'number': 110,
#   'view_type': 'Ocean View',
#   'capacity': 2,
#   'room_type': 'Double',
#   'availability': 'Occupied',
#   'last_maintenance_date': Timestamp('2025-04-02 00:00:00'),
#   'accessibility_accomodation': 'Wheelchair Access'},
#  {'room_id': 11,
#   'number': 201,
#   'view_type': 'Street View',
#   'capacity': 2,
#   'room_type': 'Single',
#   'availability': 'Available',
#   'last_maintenance_date': Timestamp('2025-03-11 00:00:00'),
#   'accessibility_accomodation': nan},
#  {'room_id': 12,
#   'number': 202,
#   'view_type': 'Street View',
#   'capacity': 2,
#   'room_type': 'Double',
#   'availability': 'Out of Service',
#   'last_maintenance_date': Timestamp('2025-02-05 00:00:00'),
#   'accessibility_accomodation': nan},
#  {'room_id': 13,
#   'number': 203,
#   'view_type': 'Ocean View',
#   'capacity': 1,
#   'room_type': 'Single',
#   'availability': 'Available',
#   'last_maintenance_date': Timestamp('2025-05-20 00:00:00'),
#   'accessibility_accomodation': 'Hearing Impairment Support'},
#  {'room_id': 14,
#   'number': 204,
#   'view_type': 'Street View',
#   'capacity': 2,
#   'room_type': 'Double',
#   'availability': 'Occupied',
#   'last_maintenance_date': Timestamp('2025-02-28 00:00:00'),
#   'accessibility_accomodation': nan},
#  {'room_id': 15,
#   'number': 205,
#   'view_type': 'Ocean View',
#   'capacity': 4,
#   'room_type': 'Penthouse',
#   'availability': 'Occupied',
#   'last_maintenance_date': Timestamp('2025-02-20 00:00:00'),
#   'accessibility_accomodation': nan},
#  {'room_id': 16,
#   'number': 206,
#   'view_type': 'Poolside',
#   'capacity': 2,
#   'room_type': 'Double',
#   'availability': 'Available',
#   'last_maintenance_date': Timestamp('2025-03-05 00:00:00'),
#   'accessibility_accomodation': 'Wheelchair Access'},
#  {'room_id': 17,
#   'number': 207,
#   'view_type': 'Ocean View',
#   'capacity': 1,
#   'room_type': 'Single',
#   'availability': 'Occupied',
#   'last_maintenance_date': Timestamp('2025-06-11 00:00:00'),
#   'accessibility_accomodation': 'Wheelchair Access'},
#  {'room_id': 18,
#   'number': 208,
#   'view_type': 'Ocean View',
#   'capacity': 2,
#   'room_type': 'Double',
#   'availability': 'Occupied',
#   'last_maintenance_date': Timestamp('2025-02-16 00:00:00'),
#   'accessibility_accomodation': nan},
#  {'room_id': 19,
#   'number': 209,
#   'view_type': 'Street View',
#   'capacity': 2,
#   'room_type': 'Double',
#   'availability': 'Available',
#   'last_maintenance_date': Timestamp('2025-01-28 00:00:00'),
#   'accessibility_accomodation': 'Wheelchair Access'},
#  {'room_id': 20,
#   'number': 210,
#   'view_type': 'Ocean View',
#   'capacity': 4,
#   'room_type': 'Penthouse',
#   'availability': 'Available',
#   'last_maintenance_date': Timestamp('2025-03-27 00:00:00'),
#   'accessibility_accomodation': 'Wheelchair Access'},
#  {'room_id': 21,
#   'number': 301,
#   'view_type': 'Ocean View',
#   'capacity': 2,
#   'room_type': 'Executive Suite',
#   'availability': 'Available',
#   'last_maintenance_date': Timestamp('2025-04-12 00:00:00'),
#   'accessibility_accomodation': 'Hearing Impairment Support'},
#  {'room_id': 22,
#   'number': 302,
#   'view_type': 'Street View',
#   'capacity': 4,
#   'room_type': 'Presidential Suite',
#   'availability': 'Occupied',
#   'last_maintenance_date': Timestamp('2025-04-12 00:00:00'),
#   'accessibility_accomodation': nan},
#  {'room_id': 23,
#   'number': 303,
#   'view_type': 'Street View',
#   'capacity': 4,
#   'room_type': 'Presidential Suite',
#   'availability': 'Out of Service',
#   'last_maintenance_date': Timestamp('2025-03-30 00:00:00'),
#   'accessibility_accomodation': 'Wheelchair Access'},
#  {'room_id': 24,
#   'number': 304,
#   'view_type': 'Ocean View',
#   'capacity': 3,
#   'room_type': 'Executive Suite',
#   'availability': 'Occupied',
#   'last_maintenance_date': Timestamp('2025-02-20 00:00:00'),
#   'accessibility_accomodation': nan},
#  {'room_id': 25,
#   'number': 305,
#   'view_type': 'Street View',
#   'capacity': 4,
#   'room_type': 'Presidential Suite',
#   'availability': 'Occupied',
#   'last_maintenance_date': Timestamp('2025-06-12 00:00:00'),
#   'accessibility_accomodation': 'Hearing Impairment Support'},
#  {'room_id': 26,
#   'number': 306,
#   'view_type': 'Ocean View',
#   'capacity': 4,
#   'room_type': 'Presidential Suite',
#   'availability': 'Occupied',
#   'last_maintenance_date': Timestamp('2025-02-04 00:00:00'),
#   'accessibility_accomodation': nan},
#  {'room_id': 27,
#   'number': 307,
#   'view_type': 'Street View',
#   'capacity': 2,
#   'room_type': 'Single',
#   'availability': 'Occupied',
#   'last_maintenance_date': Timestamp('2025-01-09 00:00:00'),
#   'accessibility_accomodation': nan},
#  {'room_id': 28,
#   'number': 308,
#   'view_type': 'Poolside',
#   'capacity': 4,
#   'room_type': 'Presidential Suite',
#   'availability': 'Occupied',
#   'last_maintenance_date': Timestamp('2025-05-07 00:00:00'),
#   'accessibility_accomodation': 'Wheelchair Access'},
#  {'room_id': 29,
#   'number': 309,
#   'view_type': 'Poolside',
#   'capacity': 3,
#   'room_type': 'Suite',
#   'availability': 'Occupied',
#   'last_maintenance_date': Timestamp('2025-05-30 00:00:00'),
#   'accessibility_accomodation': nan},
#  {'room_id': 30,
#   'number': 310,
#   'view_type': 'Street View',
#   'capacity': 4,
#   'room_type': 'Presidential Suite',
#   'availability': 'Available',
#   'last_maintenance_date': Timestamp('2025-03-23 00:00:00'),
#   'accessibility_accomodation': nan},
#  {'room_id': 31,
#   'number': 401,
#   'view_type': 'Street View',
#   'capacity': 2,
#   'room_type': 'Double',
#   'availability': 'Occupied',
#   'last_maintenance_date': Timestamp('2025-03-14 00:00:00'),
#   'accessibility_accomodation': 'Wheelchair Access'},
#  {'room_id': 32,
#   'number': 402,
#   'view_type': 'Poolside',
#   'capacity': 2,
#   'room_type': 'Double',
#   'availability': 'Available',
#   'last_maintenance_date': Timestamp('2025-05-03 00:00:00'),
#   'accessibility_accomodation': 'Wheelchair Access'},
#  {'room_id': 33,
#   'number': 403,
#   'view_type': 'Ocean View',
#   'capacity': 2,
#   'room_type': 'Double',
#   'availability': 'Out of Service',
#   'last_maintenance_date': Timestamp('2025-05-21 00:00:00'),
#   'accessibility_accomodation': nan},
#  {'room_id': 34,
#   'number': 404,
#   'view_type': 'Ocean View',
#   'capacity': 2,
#   'room_type': 'Double',
#   'availability': 'Occupied',
#   'last_maintenance_date': Timestamp('2025-05-25 00:00:00'),
#   'accessibility_accomodation': 'Wheelchair Access'},
#  {'room_id': 35,
#   'number': 405,
#   'view_type': 'Ocean View',
#   'capacity': 4,
#   'room_type': 'Penthouse',
#   'availability': 'Available',
#   'last_maintenance_date': Timestamp('2025-02-07 00:00:00'),
#   'accessibility_accomodation': nan},
#  {'room_id': 36,
#   'number': 406,
#   'view_type': 'Poolside',
#   'capacity': 2,
#   'room_type': 'Double',
#   'availability': 'Available',
#   'last_maintenance_date': Timestamp('2025-06-03 00:00:00'),
#   'accessibility_accomodation': 'Hearing Impairment Support'},
#  {'room_id': 37,
#   'number': 407,
#   'view_type': 'Ocean View',
#   'capacity': 2,
#   'room_type': 'Single',
#   'availability': 'Available',
#   'last_maintenance_date': Timestamp('2025-04-04 00:00:00'),
#   'accessibility_accomodation': nan},
#  {'room_id': 38,
#   'number': 408,
#   'view_type': 'Street View',
#   'capacity': 1,
#   'room_type': 'Single',
#   'availability': 'Available',
#   'last_maintenance_date': Timestamp('2025-04-02 00:00:00'),
#   'accessibility_accomodation': 'Hearing Impairment Support'},
#  {'room_id': 39,
#   'number': 409,
#   'view_type': 'Poolside',
#   'capacity': 1,
#   'room_type': 'Single',
#   'availability': 'Occupied',
#   'last_maintenance_date': Timestamp('2025-04-18 00:00:00'),
#   'accessibility_accomodation': 'Hearing Impairment Support'},
#  {'room_id': 40,
#   'number': 410,
#   'view_type': 'Street View',
#   'capacity': 2,
#   'room_type': 'Double',
#   'availability': 'Available',
#   'last_maintenance_date': Timestamp('2025-04-16 00:00:00'),
#   'accessibility_accomodation': 'Wheelchair Access'},
#  {'room_id': 41,
#   'number': 501,
#   'view_type': 'Ocean View',
#   'capacity': 1,
#   'room_type': 'Single',
#   'availability': 'Available',
#   'last_maintenance_date': Timestamp('2025-03-07 00:00:00'),
#   'accessibility_accomodation': nan},
#  {'room_id': 42,
#   'number': 502,
#   'view_type': 'Poolside',
#   'capacity': 2,
#   'room_type': 'Double',
#   'availability': 'Occupied',
#   'last_maintenance_date': Timestamp('2025-05-02 00:00:00'),
#   'accessibility_accomodation': nan},
#  {'room_id': 43,
#   'number': 503,
#   'view_type': 'Poolside',
#   'capacity': 1,
#   'room_type': 'Single',
#   'availability': 'Out of Service',
#   'last_maintenance_date': Timestamp('2025-06-07 00:00:00'),
#   'accessibility_accomodation': 'Wheelchair Access'},
#  {'room_id': 44,
#   'number': 504,
#   'view_type': 'Street View',
#   'capacity': 2,
#   'room_type': 'Double',
#   'availability': 'Occupied',
#   'last_maintenance_date': Timestamp('2025-04-06 00:00:00'),
#   'accessibility_accomodation': 'Hearing Impairment Support'},
#  {'room_id': 45,
#   'number': 505,
#   'view_type': 'Ocean View',
#   'capacity': 2,
#   'room_type': 'Double',
#   'availability': 'Available',
#   'last_maintenance_date': Timestamp('2025-02-03 00:00:00'),
#   'accessibility_accomodation': nan},
#  {'room_id': 46,
#   'number': 506,
#   'view_type': 'Poolside',
#   'capacity': 1,
#   'room_type': 'Single',
#   'availability': 'Out of Service',
#   'last_maintenance_date': Timestamp('2025-02-28 00:00:00'),
#   'accessibility_accomodation': nan},
#  {'room_id': 47,
#   'number': 507,
#   'view_type': 'Street View',
#   'capacity': 2,
#   'room_type': 'Double',
#   'availability': 'Available',
#   'last_maintenance_date': Timestamp('2025-06-02 00:00:00'),
#   'accessibility_accomodation': nan},
#  {'room_id': 48,
#   'number': 508,
#   'view_type': 'Street View',
#   'capacity': 2,
#   'room_type': 'Double',
#   'availability': 'Occupied',
#   'last_maintenance_date': Timestamp('2025-03-08 00:00:00'),
#   'accessibility_accomodation': nan},
#  {'room_id': 49,
#   'number': 509,
#   'view_type': 'Poolside',
#   'capacity': 2,
#   'room_type': 'Double',
#   'availability': 'Available',
#   'last_maintenance_date': Timestamp('2025-05-27 00:00:00'),
#   'accessibility_accomodation': 'Wheelchair Access'},
#  {'room_id': 50,
#   'number': 510,
#   'view_type': 'Ocean View',
#   'capacity': 1,
#   'room_type': 'Single',
#   'availability': 'Out of Service',
#   'last_maintenance_date': Timestamp('2025-04-21 00:00:00'),
#   'accessibility_accomodation': nan}]

# %%
rooms_collection = db.Rooms

# %%
rooms_collection.insert_many(rooms_dict)
# Out:
# InsertManyResult([ObjectId('683621d226350b88b8689be8'), ObjectId('683621d226350b88b8689be9'), ObjectId('683621d226350b88b8689bea'), ObjectId('683621d226350b88b8689beb'), ObjectId('683621d226350b88b8689bec'), ObjectId('683621d226350b88b8689bed'), ObjectId('683621d226350b88b8689bee'), ObjectId('683621d226350b88b8689bef'), ObjectId('683621d226350b88b8689bf0'), ObjectId('683621d226350b88b8689bf1'), ObjectId('683621d226350b88b8689bf2'), ObjectId('683621d226350b88b8689bf3'), ObjectId('683621d226350b88b8689bf4'), ObjectId('683621d226350b88b8689bf5'), ObjectId('683621d226350b88b8689bf6'), ObjectId('683621d226350b88b8689bf7'), ObjectId('683621d226350b88b8689bf8'), ObjectId('683621d226350b88b8689bf9'), ObjectId('683621d226350b88b8689bfa'), ObjectId('683621d226350b88b8689bfb'), ObjectId('683621d226350b88b8689bfc'), ObjectId('683621d226350b88b8689bfd'), ObjectId('683621d226350b88b8689bfe'), ObjectId('683621d226350b88b8689bff'), ObjectId('683621d226350b88b8689c00'), ObjectId('683621d226350b88b8689c01'), ObjectId('683621d226350b88b8689c02'), ObjectId('683621d226350b88b8689c03'), ObjectId('683621d226350b88b8689c04'), ObjectId('683621d226350b88b8689c05'), ObjectId('683621d226350b88b8689c06'), ObjectId('683621d226350b88b8689c07'), ObjectId('683621d226350b88b8689c08'), ObjectId('683621d226350b88b8689c09'), ObjectId('683621d226350b88b8689c0a'), ObjectId('683621d226350b88b8689c0b'), ObjectId('683621d226350b88b8689c0c'), ObjectId('683621d226350b88b8689c0d'), ObjectId('683621d226350b88b8689c0e'), ObjectId('683621d226350b88b8689c0f'), ObjectId('683621d226350b88b8689c10'), ObjectId('683621d226350b88b8689c11'), ObjectId('683621d226350b88b8689c12'), ObjectId('683621d226350b88b8689c13'), ObjectId('683621d226350b88b8689c14'), ObjectId('683621d226350b88b8689c15'), ObjectId('683621d226350b88b8689c16'), ObjectId('683621d226350b88b8689c17'), ObjectId('683621d226350b88b8689c18'), ObjectId('683621d226350b88b8689c19')], acknowledged=True)

# %%
collection = db.Reservations

# %%
Reservations = pd.read_excel('C:\\Users\\samue\\Downloads\\SQL project data\\Reservations.xlsx')
Reservations.head(3)
# Out:
#    reservation_id  room_id check_in_date check_out_date  is_occupied  \
# 0               1        1    2025-04-01     2025-04-02        False
# 1               2        1    2025-04-05     2025-04-09        False
# 2               3        1    2025-07-20     2025-07-25        False
#
#   cleanliness_state  guest_id
# 0           cleaned      1012
# 1           cleaned      1008
# 2           cleaned      1015

# %%
reservations_dict = Reservations.to_dict('records')
# Out:
# [{'reservation_id': 1,
#   'room_id': 1,
#   'check_in_date': Timestamp('2025-04-01 00:00:00'),
#   'check_out_date': Timestamp('2025-04-02 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'cleaned',
#   'guest_id': 1012},
#  {'reservation_id': 2,
#   'room_id': 1,
#   'check_in_date': Timestamp('2025-04-05 00:00:00'),
#   'check_out_date': Timestamp('2025-04-09 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'cleaned',
#   'guest_id': 1008},
#  {'reservation_id': 3,
#   'room_id': 1,
#   'check_in_date': Timestamp('2025-07-20 00:00:00'),
#   'check_out_date': Timestamp('2025-07-25 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'cleaned',
#   'guest_id': 1015},
#  {'reservation_id': 4,
#   'room_id': 2,
#   'check_in_date': Timestamp('2025-04-15 00:00:00'),
#   'check_out_date': Timestamp('2025-04-18 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1017},
#  {'reservation_id': 5,
#   'room_id': 2,
#   'check_in_date': Timestamp('2025-06-01 00:00:00'),
#   'check_out_date': Timestamp('2025-06-04 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1018},
#  {'reservation_id': 6,
#   'room_id': 3,
#   'check_in_date': Timestamp('2025-07-01 00:00:00'),
#   'check_out_date': Timestamp('2025-07-03 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'in progress',
#   'guest_id': 1000},
#  {'reservation_id': 7,
#   'room_id': 3,
#   'check_in_date': Timestamp('2025-06-18 00:00:00'),
#   'check_out_date': Timestamp('2025-06-22 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'in progress',
#   'guest_id': 1001},
#  {'reservation_id': 8,
#   'room_id': 3,
#   'check_in_date': Timestamp('2025-07-01 00:00:00'),
#   'check_out_date': Timestamp('2025-07-05 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'in progress',
#   'guest_id': 1002},
#  {'reservation_id': 9,
#   'room_id': 4,
#   'check_in_date': Timestamp('2025-04-20 00:00:00'),
#   'check_out_date': Timestamp('2025-04-23 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'in progress',
#   'guest_id': 1003},
#  {'reservation_id': 10,
#   'room_id': 5,
#   'check_in_date': Timestamp('2025-05-10 00:00:00'),
#   'check_out_date': Timestamp('2025-05-12 00:00:00'),
#   'is_occupied': True,
#   'cleanliness_state': 'cleaned',
#   'guest_id': 1004},
#  {'reservation_id': 11,
#   'room_id': 5,
#   'check_in_date': Timestamp('2025-06-12 00:00:00'),
#   'check_out_date': Timestamp('2025-06-15 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'cleaned',
#   'guest_id': 1005},
#  {'reservation_id': 12,
#   'room_id': 5,
#   'check_in_date': Timestamp('2025-07-02 00:00:00'),
#   'check_out_date': Timestamp('2025-07-06 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'cleaned',
#   'guest_id': 1006},
#  {'reservation_id': 13,
#   'room_id': 6,
#   'check_in_date': Timestamp('2025-04-05 00:00:00'),
#   'check_out_date': Timestamp('2025-04-07 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1007},
#  {'reservation_id': 14,
#   'room_id': 6,
#   'check_in_date': Timestamp('2025-06-25 00:00:00'),
#   'check_out_date': Timestamp('2025-06-29 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1009},
#  {'reservation_id': 15,
#   'room_id': 6,
#   'check_in_date': Timestamp('2025-07-10 00:00:00'),
#   'check_out_date': Timestamp('2025-07-13 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1010},
#  {'reservation_id': 16,
#   'room_id': 7,
#   'check_in_date': Timestamp('2025-04-22 00:00:00'),
#   'check_out_date': Timestamp('2025-04-24 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'cleaned',
#   'guest_id': 1011},
#  {'reservation_id': 17,
#   'room_id': 7,
#   'check_in_date': Timestamp('2025-06-06 00:00:00'),
#   'check_out_date': Timestamp('2025-06-09 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'cleaned',
#   'guest_id': 1013},
#  {'reservation_id': 18,
#   'room_id': 7,
#   'check_in_date': Timestamp('2025-07-01 00:00:00'),
#   'check_out_date': Timestamp('2025-07-03 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'cleaned',
#   'guest_id': 1014},
#  {'reservation_id': 19,
#   'room_id': 8,
#   'check_in_date': Timestamp('2025-04-02 00:00:00'),
#   'check_out_date': Timestamp('2025-04-04 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'cleaned',
#   'guest_id': 1016},
#  {'reservation_id': 20,
#   'room_id': 9,
#   'check_in_date': Timestamp('2025-04-30 00:00:00'),
#   'check_out_date': Timestamp('2025-05-03 00:00:00'),
#   'is_occupied': True,
#   'cleanliness_state': 'in progress',
#   'guest_id': 1019},
#  {'reservation_id': 21,
#   'room_id': 9,
#   'check_in_date': Timestamp('2025-06-10 00:00:00'),
#   'check_out_date': Timestamp('2025-06-13 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'in progress',
#   'guest_id': 1020},
#  {'reservation_id': 22,
#   'room_id': 9,
#   'check_in_date': Timestamp('2025-07-05 00:00:00'),
#   'check_out_date': Timestamp('2025-07-08 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'in progress',
#   'guest_id': 1021},
#  {'reservation_id': 23,
#   'room_id': 10,
#   'check_in_date': Timestamp('2025-04-26 00:00:00'),
#   'check_out_date': Timestamp('2025-04-27 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1023},
#  {'reservation_id': 24,
#   'room_id': 10,
#   'check_in_date': Timestamp('2025-06-20 00:00:00'),
#   'check_out_date': Timestamp('2025-06-23 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1027},
#  {'reservation_id': 25,
#   'room_id': 10,
#   'check_in_date': Timestamp('2025-07-15 00:00:00'),
#   'check_out_date': Timestamp('2025-07-19 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1028},
#  {'reservation_id': 26,
#   'room_id': 11,
#   'check_in_date': Timestamp('2025-04-10 00:00:00'),
#   'check_out_date': Timestamp('2025-04-13 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1032},
#  {'reservation_id': 27,
#   'room_id': 11,
#   'check_in_date': Timestamp('2025-06-15 00:00:00'),
#   'check_out_date': Timestamp('2025-06-18 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1034},
#  {'reservation_id': 28,
#   'room_id': 12,
#   'check_in_date': Timestamp('2025-04-08 00:00:00'),
#   'check_out_date': Timestamp('2025-04-10 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'cleaned',
#   'guest_id': 1035},
#  {'reservation_id': 29,
#   'room_id': 13,
#   'check_in_date': Timestamp('2025-06-03 00:00:00'),
#   'check_out_date': Timestamp('2025-06-05 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1037},
#  {'reservation_id': 30,
#   'room_id': 13,
#   'check_in_date': Timestamp('2025-07-01 00:00:00'),
#   'check_out_date': Timestamp('2025-07-08 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1039},
#  {'reservation_id': 31,
#   'room_id': 14,
#   'check_in_date': Timestamp('2025-04-12 00:00:00'),
#   'check_out_date': Timestamp('2025-04-14 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1040},
#  {'reservation_id': 32,
#   'room_id': 14,
#   'check_in_date': Timestamp('2025-05-25 00:00:00'),
#   'check_out_date': Timestamp('2025-05-28 00:00:00'),
#   'is_occupied': True,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1042},
#  {'reservation_id': 33,
#   'room_id': 15,
#   'check_in_date': Timestamp('2025-04-01 00:00:00'),
#   'check_out_date': Timestamp('2025-04-03 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'in progress',
#   'guest_id': 1043},
#  {'reservation_id': 34,
#   'room_id': 15,
#   'check_in_date': Timestamp('2025-06-07 00:00:00'),
#   'check_out_date': Timestamp('2025-06-11 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'in progress',
#   'guest_id': 1045},
#  {'reservation_id': 35,
#   'room_id': 15,
#   'check_in_date': Timestamp('2025-07-01 00:00:00'),
#   'check_out_date': Timestamp('2025-07-07 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'in progress',
#   'guest_id': 1046},
#  {'reservation_id': 36,
#   'room_id': 16,
#   'check_in_date': Timestamp('2025-06-03 00:00:00'),
#   'check_out_date': Timestamp('2025-06-06 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1047},
#  {'reservation_id': 37,
#   'room_id': 16,
#   'check_in_date': Timestamp('2025-07-02 00:00:00'),
#   'check_out_date': Timestamp('2025-07-05 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1048},
#  {'reservation_id': 38,
#   'room_id': 17,
#   'check_in_date': Timestamp('2025-04-01 00:00:00'),
#   'check_out_date': Timestamp('2025-04-03 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'in progress',
#   'guest_id': 1049},
#  {'reservation_id': 39,
#   'room_id': 17,
#   'check_in_date': Timestamp('2025-05-18 00:00:00'),
#   'check_out_date': Timestamp('2025-05-20 00:00:00'),
#   'is_occupied': True,
#   'cleanliness_state': 'in progress',
#   'guest_id': 1054},
#  {'reservation_id': 40,
#   'room_id': 18,
#   'check_in_date': Timestamp('2025-05-15 00:00:00'),
#   'check_out_date': Timestamp('2025-05-17 00:00:00'),
#   'is_occupied': True,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1055},
#  {'reservation_id': 41,
#   'room_id': 18,
#   'check_in_date': Timestamp('2025-06-08 00:00:00'),
#   'check_out_date': Timestamp('2025-06-13 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1056},
#  {'reservation_id': 42,
#   'room_id': 18,
#   'check_in_date': Timestamp('2025-07-10 00:00:00'),
#   'check_out_date': Timestamp('2025-07-14 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1057},
#  {'reservation_id': 43,
#   'room_id': 19,
#   'check_in_date': Timestamp('2025-04-14 00:00:00'),
#   'check_out_date': Timestamp('2025-04-16 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'cleaned',
#   'guest_id': 1059},
#  {'reservation_id': 44,
#   'room_id': 19,
#   'check_in_date': Timestamp('2025-06-18 00:00:00'),
#   'check_out_date': Timestamp('2025-06-21 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'cleaned',
#   'guest_id': 1060},
#  {'reservation_id': 45,
#   'room_id': 20,
#   'check_in_date': Timestamp('2025-06-01 00:00:00'),
#   'check_out_date': Timestamp('2025-06-05 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'in progress',
#   'guest_id': 1061},
#  {'reservation_id': 46,
#   'room_id': 20,
#   'check_in_date': Timestamp('2025-07-05 00:00:00'),
#   'check_out_date': Timestamp('2025-07-11 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'in progress',
#   'guest_id': 1062},
#  {'reservation_id': 47,
#   'room_id': 21,
#   'check_in_date': Timestamp('2025-04-25 00:00:00'),
#   'check_out_date': Timestamp('2025-04-28 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1022},
#  {'reservation_id': 48,
#   'room_id': 22,
#   'check_in_date': Timestamp('2025-04-12 00:00:00'),
#   'check_out_date': Timestamp('2025-04-14 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1024},
#  {'reservation_id': 49,
#   'room_id': 22,
#   'check_in_date': Timestamp('2025-06-12 00:00:00'),
#   'check_out_date': Timestamp('2025-06-14 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1025},
#  {'reservation_id': 50,
#   'room_id': 23,
#   'check_in_date': Timestamp('2025-04-25 00:00:00'),
#   'check_out_date': Timestamp('2025-04-29 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1026},
#  {'reservation_id': 51,
#   'room_id': 23,
#   'check_in_date': Timestamp('2025-04-05 00:00:00'),
#   'check_out_date': Timestamp('2025-04-09 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1029},
#  {'reservation_id': 52,
#   'room_id': 24,
#   'check_in_date': Timestamp('2025-05-16 00:00:00'),
#   'check_out_date': Timestamp('2025-05-20 00:00:00'),
#   'is_occupied': True,
#   'cleanliness_state': 'in progress',
#   'guest_id': 1030},
#  {'reservation_id': 53,
#   'room_id': 25,
#   'check_in_date': Timestamp('2025-04-22 00:00:00'),
#   'check_out_date': Timestamp('2025-04-24 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1031},
#  {'reservation_id': 54,
#   'room_id': 25,
#   'check_in_date': Timestamp('2025-05-07 00:00:00'),
#   'check_out_date': Timestamp('2025-05-10 00:00:00'),
#   'is_occupied': True,
#   'cleanliness_state': 'in progress',
#   'guest_id': 1033},
#  {'reservation_id': 55,
#   'room_id': 26,
#   'check_in_date': Timestamp('2025-06-15 00:00:00'),
#   'check_out_date': Timestamp('2025-06-18 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1036},
#  {'reservation_id': 56,
#   'room_id': 27,
#   'check_in_date': Timestamp('2025-05-10 00:00:00'),
#   'check_out_date': Timestamp('2025-05-13 00:00:00'),
#   'is_occupied': True,
#   'cleanliness_state': 'cleaned',
#   'guest_id': 1038},
#  {'reservation_id': 57,
#   'room_id': 27,
#   'check_in_date': Timestamp('2025-06-02 00:00:00'),
#   'check_out_date': Timestamp('2025-06-05 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'cleaned',
#   'guest_id': 1041},
#  {'reservation_id': 58,
#   'room_id': 28,
#   'check_in_date': Timestamp('2025-05-03 00:00:00'),
#   'check_out_date': Timestamp('2025-05-05 00:00:00'),
#   'is_occupied': True,
#   'cleanliness_state': 'cleaned',
#   'guest_id': 1044},
#  {'reservation_id': 59,
#   'room_id': 28,
#   'check_in_date': Timestamp('2025-06-10 00:00:00'),
#   'check_out_date': Timestamp('2025-06-13 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'cleaned',
#   'guest_id': 1050},
#  {'reservation_id': 60,
#   'room_id': 29,
#   'check_in_date': Timestamp('2025-04-28 00:00:00'),
#   'check_out_date': Timestamp('2025-05-02 00:00:00'),
#   'is_occupied': True,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1051},
#  {'reservation_id': 61,
#   'room_id': 29,
#   'check_in_date': Timestamp('2025-06-01 00:00:00'),
#   'check_out_date': Timestamp('2025-06-04 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1052},
#  {'reservation_id': 62,
#   'room_id': 30,
#   'check_in_date': Timestamp('2025-04-03 00:00:00'),
#   'check_out_date': Timestamp('2025-04-05 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'cleaned',
#   'guest_id': 1053},
#  {'reservation_id': 63,
#   'room_id': 30,
#   'check_in_date': Timestamp('2025-06-06 00:00:00'),
#   'check_out_date': Timestamp('2025-06-10 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'cleaned',
#   'guest_id': 1058},
#  {'reservation_id': 64,
#   'room_id': 31,
#   'check_in_date': Timestamp('2025-05-06 00:00:00'),
#   'check_out_date': Timestamp('2025-05-09 00:00:00'),
#   'is_occupied': True,
#   'cleanliness_state': 'cleaned',
#   'guest_id': 1094},
#  {'reservation_id': 65,
#   'room_id': 31,
#   'check_in_date': Timestamp('2025-06-11 00:00:00'),
#   'check_out_date': Timestamp('2025-06-15 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'cleaned',
#   'guest_id': 1095},
#  {'reservation_id': 66,
#   'room_id': 32,
#   'check_in_date': Timestamp('2025-04-12 00:00:00'),
#   'check_out_date': Timestamp('2025-04-14 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'cleaned',
#   'guest_id': 1096},
#  {'reservation_id': 67,
#   'room_id': 32,
#   'check_in_date': Timestamp('2025-06-20 00:00:00'),
#   'check_out_date': Timestamp('2025-06-23 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'cleaned',
#   'guest_id': 1097},
#  {'reservation_id': 68,
#   'room_id': 33,
#   'check_in_date': Timestamp('2025-07-02 00:00:00'),
#   'check_out_date': Timestamp('2025-07-04 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1098},
#  {'reservation_id': 69,
#   'room_id': 34,
#   'check_in_date': Timestamp('2025-04-25 00:00:00'),
#   'check_out_date': Timestamp('2025-04-27 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1099},
#  {'reservation_id': 70,
#   'room_id': 35,
#   'check_in_date': Timestamp('2025-06-08 00:00:00'),
#   'check_out_date': Timestamp('2025-06-11 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'cleaned',
#   'guest_id': 1100},
#  {'reservation_id': 71,
#   'room_id': 36,
#   'check_in_date': Timestamp('2025-04-02 00:00:00'),
#   'check_out_date': Timestamp('2025-04-05 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'in progress',
#   'guest_id': 1101},
#  {'reservation_id': 72,
#   'room_id': 37,
#   'check_in_date': Timestamp('2025-06-12 00:00:00'),
#   'check_out_date': Timestamp('2025-06-15 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1081},
#  {'reservation_id': 73,
#   'room_id': 38,
#   'check_in_date': Timestamp('2025-04-07 00:00:00'),
#   'check_out_date': Timestamp('2025-04-10 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'cleaned',
#   'guest_id': 1082},
#  {'reservation_id': 74,
#   'room_id': 39,
#   'check_in_date': Timestamp('2025-05-01 00:00:00'),
#   'check_out_date': Timestamp('2025-05-04 00:00:00'),
#   'is_occupied': True,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1083},
#  {'reservation_id': 75,
#   'room_id': 40,
#   'check_in_date': Timestamp('2025-04-18 00:00:00'),
#   'check_out_date': Timestamp('2025-04-21 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'in progress',
#   'guest_id': 1084},
#  {'reservation_id': 76,
#   'room_id': 41,
#   'check_in_date': Timestamp('2025-04-15 00:00:00'),
#   'check_out_date': Timestamp('2025-04-17 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1085},
#  {'reservation_id': 77,
#   'room_id': 41,
#   'check_in_date': Timestamp('2025-06-18 00:00:00'),
#   'check_out_date': Timestamp('2025-06-21 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1086},
#  {'reservation_id': 78,
#   'room_id': 41,
#   'check_in_date': Timestamp('2025-06-10 00:00:00'),
#   'check_out_date': Timestamp('2025-06-14 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1087},
#  {'reservation_id': 79,
#   'room_id': 42,
#   'check_in_date': Timestamp('2025-05-10 00:00:00'),
#   'check_out_date': Timestamp('2025-05-13 00:00:00'),
#   'is_occupied': True,
#   'cleanliness_state': 'cleaned',
#   'guest_id': 1088},
#  {'reservation_id': 80,
#   'room_id': 42,
#   'check_in_date': Timestamp('2025-06-21 00:00:00'),
#   'check_out_date': Timestamp('2025-06-24 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'cleaned',
#   'guest_id': 1089},
#  {'reservation_id': 81,
#   'room_id': 43,
#   'check_in_date': Timestamp('2025-06-05 00:00:00'),
#   'check_out_date': Timestamp('2025-06-08 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'in progress',
#   'guest_id': 1090},
#  {'reservation_id': 82,
#   'room_id': 43,
#   'check_in_date': Timestamp('2025-06-10 00:00:00'),
#   'check_out_date': Timestamp('2025-06-13 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'in progress',
#   'guest_id': 1091},
#  {'reservation_id': 83,
#   'room_id': 44,
#   'check_in_date': Timestamp('2025-04-27 00:00:00'),
#   'check_out_date': Timestamp('2025-04-29 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1092},
#  {'reservation_id': 84,
#   'room_id': 44,
#   'check_in_date': Timestamp('2025-06-14 00:00:00'),
#   'check_out_date': Timestamp('2025-06-17 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1093},
#  {'reservation_id': 85,
#   'room_id': 45,
#   'check_in_date': Timestamp('2025-06-12 00:00:00'),
#   'check_out_date': Timestamp('2025-06-14 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'cleaned',
#   'guest_id': 1069},
#  {'reservation_id': 86,
#   'room_id': 45,
#   'check_in_date': Timestamp('2025-07-01 00:00:00'),
#   'check_out_date': Timestamp('2025-07-05 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'cleaned',
#   'guest_id': 1070},
#  {'reservation_id': 87,
#   'room_id': 46,
#   'check_in_date': Timestamp('2025-04-05 00:00:00'),
#   'check_out_date': Timestamp('2025-04-07 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'in progress',
#   'guest_id': 1071},
#  {'reservation_id': 88,
#   'room_id': 46,
#   'check_in_date': Timestamp('2025-06-27 00:00:00'),
#   'check_out_date': Timestamp('2025-06-30 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'in progress',
#   'guest_id': 1072},
#  {'reservation_id': 89,
#   'room_id': 47,
#   'check_in_date': Timestamp('2025-06-03 00:00:00'),
#   'check_out_date': Timestamp('2025-06-06 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'cleaned',
#   'guest_id': 1073},
#  {'reservation_id': 90,
#   'room_id': 47,
#   'check_in_date': Timestamp('2025-04-23 00:00:00'),
#   'check_out_date': Timestamp('2025-04-26 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'cleaned',
#   'guest_id': 1074},
#  {'reservation_id': 91,
#   'room_id': 48,
#   'check_in_date': Timestamp('2025-06-19 00:00:00'),
#   'check_out_date': Timestamp('2025-06-22 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1075},
#  {'reservation_id': 92,
#   'room_id': 48,
#   'check_in_date': Timestamp('2025-05-15 00:00:00'),
#   'check_out_date': Timestamp('2025-05-18 00:00:00'),
#   'is_occupied': True,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1076},
#  {'reservation_id': 93,
#   'room_id': 49,
#   'check_in_date': Timestamp('2025-06-22 00:00:00'),
#   'check_out_date': Timestamp('2025-06-25 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1077},
#  {'reservation_id': 94,
#   'room_id': 50,
#   'check_in_date': Timestamp('2025-07-05 00:00:00'),
#   'check_out_date': Timestamp('2025-07-09 00:00:00'),
#   'is_occupied': False,
#   'cleanliness_state': 'in progress',
#   'guest_id': 1078},
#  {'reservation_id': 95,
#   'room_id': 7,
#   'check_in_date': Timestamp('2025-05-23 00:00:00'),
#   'check_out_date': Timestamp('2025-05-27 00:00:00'),
#   'is_occupied': True,
#   'cleanliness_state': 'cleaned',
#   'guest_id': 1079},
#  {'reservation_id': 96,
#   'room_id': 10,
#   'check_in_date': Timestamp('2025-05-15 00:00:00'),
#   'check_out_date': Timestamp('2025-05-25 00:00:00'),
#   'is_occupied': True,
#   'cleanliness_state': 'cleaned',
#   'guest_id': 1080},
#  {'reservation_id': 97,
#   'room_id': 15,
#   'check_in_date': Timestamp('2025-05-20 00:00:00'),
#   'check_out_date': Timestamp('2025-05-22 00:00:00'),
#   'is_occupied': True,
#   'cleanliness_state': 'in progress',
#   'guest_id': 1063},
#  {'reservation_id': 98,
#   'room_id': 34,
#   'check_in_date': Timestamp('2025-05-27 00:00:00'),
#   'check_out_date': Timestamp('2025-06-01 00:00:00'),
#   'is_occupied': True,
#   'cleanliness_state': 'cleaned',
#   'guest_id': 1064},
#  {'reservation_id': 99,
#   'room_id': 22,
#   'check_in_date': Timestamp('2025-04-29 00:00:00'),
#   'check_out_date': Timestamp('2025-05-04 00:00:00'),
#   'is_occupied': True,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1065},
#  {'reservation_id': 100,
#   'room_id': 34,
#   'check_in_date': Timestamp('2025-05-10 00:00:00'),
#   'check_out_date': Timestamp('2025-05-28 00:00:00'),
#   'is_occupied': True,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1066},
#  {'reservation_id': 101,
#   'room_id': 26,
#   'check_in_date': Timestamp('2025-05-17 00:00:00'),
#   'check_out_date': Timestamp('2025-05-19 00:00:00'),
#   'is_occupied': True,
#   'cleanliness_state': 'unclean',
#   'guest_id': 1067},
#  {'reservation_id': 102,
#   'room_id': 44,
#   'check_in_date': Timestamp('2025-05-12 00:00:00'),
#   'check_out_date': Timestamp('2025-05-20 00:00:00'),
#   'is_occupied': True,
#   'cleanliness_state': 'cleaned',
#   'guest_id': 1068}]

# %%
reservations_collection = db.Reservations

# %%
reservations_collection.insert_many(reservations_dict)
# Out:
# InsertManyResult([ObjectId('683622f426350b88b8689c1a'), ObjectId('683622f426350b88b8689c1b'), ObjectId('683622f426350b88b8689c1c'), ObjectId('683622f426350b88b8689c1d'), ObjectId('683622f426350b88b8689c1e'), ObjectId('683622f426350b88b8689c1f'), ObjectId('683622f426350b88b8689c20'), ObjectId('683622f426350b88b8689c21'), ObjectId('683622f426350b88b8689c22'), ObjectId('683622f426350b88b8689c23'), ObjectId('683622f426350b88b8689c24'), ObjectId('683622f426350b88b8689c25'), ObjectId('683622f426350b88b8689c26'), ObjectId('683622f426350b88b8689c27'), ObjectId('683622f426350b88b8689c28'), ObjectId('683622f426350b88b8689c29'), ObjectId('683622f426350b88b8689c2a'), ObjectId('683622f426350b88b8689c2b'), ObjectId('683622f426350b88b8689c2c'), ObjectId('683622f426350b88b8689c2d'), ObjectId('683622f426350b88b8689c2e'), ObjectId('683622f426350b88b8689c2f'), ObjectId('683622f426350b88b8689c30'), ObjectId('683622f426350b88b8689c31'), ObjectId('683622f426350b88b8689c32'), ObjectId('683622f426350b88b8689c33'), ObjectId('683622f426350b88b8689c34'), ObjectId('683622f426350b88b8689c35'), ObjectId('683622f426350b88b8689c36'), ObjectId('683622f426350b88b8689c37'), ObjectId('683622f426350b88b8689c38'), ObjectId('683622f426350b88b8689c39'), ObjectId('683622f426350b88b8689c3a'), ObjectId('683622f426350b88b8689c3b'), ObjectId('683622f426350b88b8689c3c'), ObjectId('683622f426350b88b8689c3d'), ObjectId('683622f426350b88b8689c3e'), ObjectId('683622f426350b88b8689c3f'), ObjectId('683622f426350b88b8689c40'), ObjectId('683622f426350b88b8689c41'), ObjectId('683622f426350b88b8689c42'), ObjectId('683622f426350b88b8689c43'), ObjectId('683622f426350b88b8689c44'), ObjectId('683622f426350b88b8689c45'), ObjectId('683622f426350b88b8689c46'), ObjectId('683622f426350b88b8689c47'), ObjectId('683622f426350b88b8689c48'), ObjectId('683622f426350b88b8689c49'), ObjectId('683622f426350b88b8689c4a'), ObjectId('683622f426350b88b8689c4b'), ObjectId('683622f426350b88b8689c4c'), ObjectId('683622f426350b88b8689c4d'), ObjectId('683622f426350b88b8689c4e'), ObjectId('683622f426350b88b8689c4f'), ObjectId('683622f426350b88b8689c50'), ObjectId('683622f426350b88b8689c51'), ObjectId('683622f426350b88b8689c52'), ObjectId('683622f426350b88b8689c53'), ObjectId('683622f426350b88b8689c54'), ObjectId('683622f426350b88b8689c55'), ObjectId('683622f426350b88b8689c56'), ObjectId('683622f426350b88b8689c57'), ObjectId('683622f426350b88b8689c58'), ObjectId('683622f426350b88b8689c59'), ObjectId('683622f426350b88b8689c5a'), ObjectId('683622f426350b88b8689c5b'), ObjectId('683622f426350b88b8689c5c'), ObjectId('683622f426350b88b8689c5d'), ObjectId('683622f426350b88b8689c5e'), ObjectId('683622f426350b88b8689c5f'), ObjectId('683622f426350b88b8689c60'), ObjectId('683622f426350b88b8689c61'), ObjectId('683622f426350b88b8689c62'), ObjectId('683622f426350b88b8689c63'), ObjectId('683622f426350b88b8689c64'), ObjectId('683622f426350b88b8689c65'), ObjectId('683622f426350b88b8689c66'), ObjectId('683622f426350b88b8689c67'), ObjectId('683622f426350b88b8689c68'), ObjectId('683622f426350b88b8689c69'), ObjectId('683622f426350b88b8689c6a'), ObjectId('683622f426350b88b8689c6b'), ObjectId('683622f426350b88b8689c6c'), ObjectId('683622f426350b88b8689c6d'), ObjectId('683622f426350b88b8689c6e'), ObjectId('683622f426350b88b8689c6f'), ObjectId('683622f426350b88b8689c70'), ObjectId('683622f426350b88b8689c71'), ObjectId('683622f426350b88b8689c72'), ObjectId('683622f426350b88b8689c73'), ObjectId('683622f426350b88b8689c74'), ObjectId('683622f426350b88b8689c75'), ObjectId('683622f426350b88b8689c76'), ObjectId('683622f426350b88b8689c77'), ObjectId('683622f426350b88b8689c78'), ObjectId('683622f426350b88b8689c79'), ObjectId('683622f426350b88b8689c7a'), ObjectId('683622f426350b88b8689c7b'), ObjectId('683622f426350b88b8689c7c'), ObjectId('683622f426350b88b8689c7d'), ObjectId('683622f426350b88b8689c7e'), ObjectId('683622f426350b88b8689c7f')], acknowledged=True)

# %%
guests = pd.read_excel('C:\\Users\\samue\\Downloads\\SQL project data\\Guests.xlsx')
guests.head(3)
# Out:
#   First_Name Last_Name  Guest_ID  \
# 0      Kevin  Thompson      1000
# 1     Travis  Williams      1001
# 2     Colton    Harmon      1002
#
#                                              Address    Phone number  \
# 0  165 Parrish Stravenue Apt. 494, Dalehaven, FL ...  (478) 686-3375
# 1        8514 Lindsay Vista, New Sarahview, HI 36319  (069) 033-1190
# 2  5022 Jones Streets Apt. 183, Barnesmouth, MN 4...  (067) 383-0284
#
#                       Email Membership Status
# 0        fmiles@hotmail.com            Silver
# 1  christopher18@mccann.net            Silver
# 2       wwillis@hotmail.com          Standard

# %%
guests_dict = guests.to_dict('records')
# Out:
# [{'First_Name': 'Kevin',
#   'Last_Name': 'Thompson',
#   'Guest_ID': 1000,
#   'Address': '165 Parrish Stravenue Apt. 494, Dalehaven, FL 86580',
#   'Phone number': '(478) 686-3375',
#   'Email': 'fmiles@hotmail.com',
#   'Membership Status': 'Silver'},
#  {'First_Name': 'Travis',
#   'Last_Name': 'Williams',
#   'Guest_ID': 1001,
#   'Address': '8514 Lindsay Vista, New Sarahview, HI 36319',
#   'Phone number': '(069) 033-1190',
#   'Email': 'christopher18@mccann.net',
#   'Membership Status': 'Silver'},
#  {'First_Name': 'Colton',
#   'Last_Name': 'Harmon',
#   'Guest_ID': 1002,
#   'Address': '5022 Jones Streets Apt. 183, Barnesmouth, MN 41347',
#   'Phone number': '(067) 383-0284',
#   'Email': 'wwillis@hotmail.com',
#   'Membership Status': 'Standard'},
#  {'First_Name': 'Paige',
#   'Last_Name': 'Fox',
#   'Guest_ID': 1003,
#   'Address': '22901 Ramos Manors, Lawsonchester, IL 99452',
#   'Phone number': '(342) 836-4408',
#   'Email': 'holly30@miller.com',
#   'Membership Status': 'Standard'},
#  {'First_Name': 'Derek',
#   'Last_Name': 'Reese',
#   'Guest_ID': 1004,
#   'Address': '1497 Williams Locks Apt. 034, Port Derrick, LA 43508',
#   'Phone number': '(056) 856-6246',
#   'Email': 'parkerjudith@hotmail.com',
#   'Membership Status': 'Standard'},
#  {'First_Name': 'Shawn',
#   'Last_Name': 'Alvarez',
#   'Guest_ID': 1005,
#   'Address': '622 Patel Forks Suite 160, Smithland, MD 75966',
#   'Phone number': '(342) 708-6688',
#   'Email': 'smithderrick@martin.net',
#   'Membership Status': 'Silver'},
#  {'First_Name': 'Ellen',
#   'Last_Name': 'Strickland',
#   'Guest_ID': 1006,
#   'Address': '641 Smith Islands Apt. 975, South Meganbury, OR 52988',
#   'Phone number': '(351) 751-8304',
#   'Email': 'nathanbrady@yahoo.com',
#   'Membership Status': 'Standard'},
#  {'First_Name': 'Julia',
#   'Last_Name': 'Palmer',
#   'Guest_ID': 1007,
#   'Address': '5352 William Crescent Apt. 552, North Dwayne, HI 79458',
#   'Phone number': '(139) 837-3540',
#   'Email': 'rogersruben@brown.com',
#   'Membership Status': 'Standard'},
#  {'First_Name': 'Sonya',
#   'Last_Name': 'Rodriguez',
#   'Guest_ID': 1008,
#   'Address': '77997 Lin Road, Edwardland, NV 83257',
#   'Phone number': '(393) 638-5467',
#   'Email': 'ddixon@yahoo.com',
#   'Membership Status': 'Gold'},
#  {'First_Name': 'Robert',
#   'Last_Name': 'Gordon',
#   'Guest_ID': 1009,
#   'Address': '058 Lance Mission Apt. 054, Lake Michelleland, PA 66963',
#   'Phone number': '(587) 717-5355',
#   'Email': 'eric19@sharp.com',
#   'Membership Status': 'Standard'},
#  {'First_Name': 'Julia',
#   'Last_Name': 'Dougherty',
#   'Guest_ID': 1010,
#   'Address': '9359 Mason Circle, Garciamouth, CO 66633',
#   'Phone number': '(204) 899-6423',
#   'Email': 'brandoncox@white.net',
#   'Membership Status': 'Silver'},
#  {'First_Name': 'Eric',
#   'Last_Name': 'Williams',
#   'Guest_ID': 1011,
#   'Address': '77889 Michael Haven, Ortizmouth, PA 07364',
#   'Phone number': '(785) 477-7252',
#   'Email': 'marcbutler@hotmail.com',
#   'Membership Status': 'Gold'},
#  {'First_Name': 'Robert',
#   'Last_Name': 'Logan',
#   'Guest_ID': 1012,
#   'Address': '51864 Cummings Shoals Apt. 519, West Kyle, UT 87288',
#   'Phone number': '(808) 010-0623',
#   'Email': 'margaret95@gmail.com',
#   'Membership Status': 'Platinum'},
#  {'First_Name': 'Corey',
#   'Last_Name': 'Camacho',
#   'Guest_ID': 1013,
#   'Address': '8652 Debbie Manors, Andrewport, IL 45292',
#   'Phone number': '(875) 099-7700',
#   'Email': 'jeffreyblack@finley.info',
#   'Membership Status': 'Silver'},
#  {'First_Name': 'Tracy',
#   'Last_Name': 'Boyd',
#   'Guest_ID': 1014,
#   'Address': 'USCGC Lee, FPO AE 20809',
#   'Phone number': '(084) 840-8621',
#   'Email': 'mark87@gmail.com',
#   'Membership Status': 'Silver'},
#  {'First_Name': 'Ricky',
#   'Last_Name': 'Ellis',
#   'Guest_ID': 1015,
#   'Address': '880 Walter River, New Nicholas, HI 91313',
#   'Phone number': '(398) 454-6156',
#   'Email': 'kellymueller@hotmail.com',
#   'Membership Status': 'Platinum'},
#  {'First_Name': 'Stephanie',
#   'Last_Name': 'Maynard',
#   'Guest_ID': 1016,
#   'Address': '706 Rhodes Freeway, Bishopmouth, ND 31849',
#   'Phone number': '(410) 166-6870',
#   'Email': 'frichardson@oconnor.com',
#   'Membership Status': 'Silver'},
#  {'First_Name': 'Antonio',
#   'Last_Name': 'Brown',
#   'Guest_ID': 1017,
#   'Address': '59774 Shaw Manor Apt. 392, Brettfort, MN 73185',
#   'Phone number': '(659) 180-3397',
#   'Email': 'randolphandrew@reed.com',
#   'Membership Status': 'Platinum'},
#  {'First_Name': 'Mitchell',
#   'Last_Name': 'Mendoza',
#   'Guest_ID': 1018,
#   'Address': 'USS Mitchell, FPO AE 36256',
#   'Phone number': '(890) 250-3926',
#   'Email': 'usweeney@garcia-moreno.com',
#   'Membership Status': 'Platinum'},
#  {'First_Name': 'Scott',
#   'Last_Name': 'Morales',
#   'Guest_ID': 1019,
#   'Address': '1375 Robert Locks, Joeland, IN 04195',
#   'Phone number': '(968) 562-1850',
#   'Email': 'jwoodward@hotmail.com',
#   'Membership Status': 'Silver'},
#  {'First_Name': 'Stephanie',
#   'Last_Name': 'Parks',
#   'Guest_ID': 1020,
#   'Address': '522 Justin Village, Hortonberg, VT 61988',
#   'Phone number': '(599) 965-0477',
#   'Email': 'williamsjesse@hotmail.com',
#   'Membership Status': 'Standard'},
#  {'First_Name': 'Melissa',
#   'Last_Name': 'Henry',
#   'Guest_ID': 1021,
#   'Address': '04328 Rodriguez Heights, West David, MT 84249',
#   'Phone number': '(629) 619-4311',
#   'Email': 'stephen19@gmail.com',
#   'Membership Status': 'Standard'},
#  {'First_Name': 'Cory',
#   'Last_Name': 'Browning',
#   'Guest_ID': 1022,
#   'Address': '17980 Jennifer Highway Suite 095, New Robert, TN 11722',
#   'Phone number': '(655) 110-4754',
#   'Email': 'kjones@graham.com',
#   'Membership Status': 'Platinum'},
#  {'First_Name': 'Gina',
#   'Last_Name': 'Jones',
#   'Guest_ID': 1023,
#   'Address': '88888 Peter Mountains Apt. 654, West Kristinastad, VA 86628',
#   'Phone number': '(678) 886-1015',
#   'Email': 'melissa65@yahoo.com',
#   'Membership Status': 'Gold'},
#  {'First_Name': 'Amy',
#   'Last_Name': 'Miller',
#   'Guest_ID': 1024,
#   'Address': '05852 Pollard Neck Apt. 217, West Jamesborough, AZ 41866',
#   'Phone number': '(604) 661-8398',
#   'Email': 'jesus32@hotmail.com',
#   'Membership Status': 'Platinum'},
#  {'First_Name': 'Tiffany',
#   'Last_Name': 'Franklin',
#   'Guest_ID': 1025,
#   'Address': 'USCGC Hays, FPO AP 62550',
#   'Phone number': '(444) 721-2646',
#   'Email': 'danielcole@russell-herrera.com',
#   'Membership Status': 'Platinum'},
#  {'First_Name': 'Michael',
#   'Last_Name': 'Jones',
#   'Guest_ID': 1026,
#   'Address': '5054 Lauren Mews, Paulfurt, HI 65539',
#   'Phone number': '(437) 993-7124',
#   'Email': 'steven11@gmail.com',
#   'Membership Status': 'Platinum'},
#  {'First_Name': 'Raymond',
#   'Last_Name': 'Hill',
#   'Guest_ID': 1027,
#   'Address': '416 Ryan View Apt. 845, North Markport, NV 79487',
#   'Phone number': '(575) 692-4593',
#   'Email': 'lewismelissa@gmail.com',
#   'Membership Status': 'Standard'},
#  {'First_Name': 'Kevin',
#   'Last_Name': 'Thompson',
#   'Guest_ID': 1028,
#   'Address': '166 Parrish Stravenue Apt. 494, Dalehaven, FL 86580',
#   'Phone number': '(478) 686-3376',
#   'Email': 'fmiles@hotmail.com',
#   'Membership Status': 'Standard'},
#  {'First_Name': 'Travis',
#   'Last_Name': 'Williams',
#   'Guest_ID': 1029,
#   'Address': '8515 Lindsay Vista, New Sarahview, HI 36319',
#   'Phone number': '(069) 033-1191',
#   'Email': 'christopher18@mccann.net',
#   'Membership Status': 'Platinum'},
#  {'First_Name': 'Colton',
#   'Last_Name': 'Harmon',
#   'Guest_ID': 1030,
#   'Address': '5023 Jones Streets Apt. 183, Barnesmouth, MN 41347',
#   'Phone number': '(067) 383-0285',
#   'Email': 'wwillis@hotmail.com',
#   'Membership Status': 'Gold'},
#  {'First_Name': 'Paige',
#   'Last_Name': 'Fox',
#   'Guest_ID': 1031,
#   'Address': '22902 Ramos Manors, Lawsonchester, IL 99452',
#   'Phone number': '(342) 836-4409',
#   'Email': 'holly30@miller.com',
#   'Membership Status': 'Standard'},
#  {'First_Name': 'Darlene',
#   'Last_Name': 'Chavez',
#   'Guest_ID': 1033,
#   'Address': '0589 Mcdonald Plaza, New Nicole, ME 52688',
#   'Phone number': '(982) 507-1461',
#   'Email': 'zunderwood@johnson-vega.com',
#   'Membership Status': 'Silver'},
#  {'First_Name': 'Carla',
#   'Last_Name': 'Jacobs',
#   'Guest_ID': 1034,
#   'Address': 'Unit 7866 Box 9125, DPO AP 10221',
#   'Phone number': '(573) 875-7177',
#   'Email': 'rebekahhill@yahoo.com',
#   'Membership Status': 'Silver'},
#  {'First_Name': 'Andrew',
#   'Last_Name': 'Garcia',
#   'Guest_ID': 1035,
#   'Address': '89226 Marie Path Apt. 422, Sarahbury, NC 37731',
#   'Phone number': '(105) 123-8282',
#   'Email': 'mendezchristina@phillips.com',
#   'Membership Status': 'Silver'},
#  {'First_Name': 'Kristin',
#   'Last_Name': 'Miles',
#   'Guest_ID': 1036,
#   'Address': '84249 Wayne Extension Apt. 299, Meganshire, AK 11147',
#   'Phone number': '(362) 266-0937',
#   'Email': 'patrick63@wilkerson.net',
#   'Membership Status': 'Platinum'},
#  {'First_Name': 'John',
#   'Last_Name': 'Farrell',
#   'Guest_ID': 1037,
#   'Address': '396 Tyler Road Suite 473, Evansland, AR 21220',
#   'Phone number': '(334) 191-8255',
#   'Email': 'wcasey@stephens-washington.org',
#   'Membership Status': 'Silver'},
#  {'First_Name': 'David',
#   'Last_Name': 'Curtis',
#   'Guest_ID': 1038,
#   'Address': '3592 Hensley Island Suite 625, West Johnville, NV 32996',
#   'Phone number': '(785) 969-6915',
#   'Email': 'bnelson@yahoo.com',
#   'Membership Status': 'Platinum'},
#  {'First_Name': 'Anne',
#   'Last_Name': 'Mack',
#   'Guest_ID': 1039,
#   'Address': '6963 Lisa Ports, Jamesburgh, NY 61687',
#   'Phone number': '(499) 125-1341',
#   'Email': 'huangkimberly@stokes.net',
#   'Membership Status': 'Silver'},
#  {'First_Name': 'Casey',
#   'Last_Name': 'Le',
#   'Guest_ID': 1040,
#   'Address': '0168 Levy Forge Suite 004, Harperfort, ND 01572',
#   'Phone number': '(692) 966-2782',
#   'Email': 'terrigarcia@hotmail.com',
#   'Membership Status': 'Gold'},
#  {'First_Name': 'Kathy',
#   'Last_Name': 'Lewis',
#   'Guest_ID': 1041,
#   'Address': '45650 Williams Points Apt. 584, South Williamside, RI 89682',
#   'Phone number': '(225) 790-5072',
#   'Email': 'amanda03@bradford.com',
#   'Membership Status': 'Platinum'},
#  {'First_Name': 'Jamie',
#   'Last_Name': 'Hayes',
#   'Guest_ID': 1042,
#   'Address': '65585 James Pass, Porterton, DC 94032',
#   'Phone number': '(676) 772-1903',
#   'Email': 'brittanydrake@howard.com',
#   'Membership Status': 'Silver'},
#  {'First_Name': 'Jason',
#   'Last_Name': 'Perez',
#   'Guest_ID': 1043,
#   'Address': '729 Mark Ridge Suite 269, Brittneyhaven, NY 70275',
#   'Phone number': '(842) 797-8819',
#   'Email': 'marycochran@weaver-thompson.com',
#   'Membership Status': 'Standard'},
#  {'First_Name': 'Molly',
#   'Last_Name': 'Morgan',
#   'Guest_ID': 1044,
#   'Address': '0551 Silva Underpass Apt. 974, Lake Brett, GA 69213',
#   'Phone number': '(807) 836-1340',
#   'Email': 'halljeffery@woods.com',
#   'Membership Status': 'Platinum'},
#  {'First_Name': 'Mark',
#   'Last_Name': 'Chavez',
#   'Guest_ID': 1045,
#   'Address': '30913 Scott Manor Apt. 636, Salaston, DC 68485',
#   'Phone number': '(713) 395-9629',
#   'Email': 'samantharichard@yahoo.com',
#   'Membership Status': 'Standard'},
#  {'First_Name': 'Dylan',
#   'Last_Name': 'Perry',
#   'Guest_ID': 1046,
#   'Address': '786 Frye Mount Suite 854, Leebury, OH 39625',
#   'Phone number': '(958) 498-2544',
#   'Email': 'hernandezjanet@schroeder.com',
#   'Membership Status': 'Standard'},
#  {'First_Name': 'Rachel',
#   'Last_Name': 'Davis',
#   'Guest_ID': 1047,
#   'Address': '3757 Castro Underpass Suite 419, Huangfurt, MI 19699',
#   'Phone number': '(260) 422-3253',
#   'Email': 'janet69@rogers.com',
#   'Membership Status': 'Standard'},
#  {'First_Name': 'Aaron',
#   'Last_Name': 'Simmons',
#   'Guest_ID': 1048,
#   'Address': '157 Burgess Forest Apt. 848, Derrickshire, IA 07154',
#   'Phone number': '(667) 116-8457',
#   'Email': 'fconner@stewart.org',
#   'Membership Status': 'Standard'},
#  {'First_Name': 'Michele',
#   'Last_Name': 'Ortega',
#   'Guest_ID': 1049,
#   'Address': '301 Rivera Mountains, Lake Kellitown, GA 53835',
#   'Phone number': '(175) 186-3637',
#   'Email': 'elizabetholsen@yahoo.com',
#   'Membership Status': 'Silver'},
#  {'First_Name': 'Duane',
#   'Last_Name': 'Brooks',
#   'Guest_ID': 1050,
#   'Address': '3454 Rebecca Corners Apt. 802, Khanburgh, AZ 52535',
#   'Phone number': '(892) 975-0017',
#   'Email': 'david09@yahoo.com',
#   'Membership Status': 'Silver'},
#  {'First_Name': 'David',
#   'Last_Name': 'Hernandez',
#   'Guest_ID': 1051,
#   'Address': '400 Bradley Coves, Justinside, NM 18090',
#   'Phone number': '(706) 324-2415',
#   'Email': 'carriemccall@walker.com',
#   'Membership Status': 'Platinum'},
#  {'First_Name': 'John',
#   'Last_Name': 'Leblanc',
#   'Guest_ID': 1052,
#   'Address': '3152 Wong Stravenue Apt. 054, East Cheryl, MO 56560',
#   'Phone number': '(064) 361-1037',
#   'Email': 'youngtoni@gmail.com',
#   'Membership Status': 'Platinum'},
#  {'First_Name': 'Greg',
#   'Last_Name': 'Jones',
#   'Guest_ID': 1053,
#   'Address': '1227 Boyle Avenue, Patrickmouth, KY 43705',
#   'Phone number': '(870) 051-6271',
#   'Email': 'sean43@steele.com',
#   'Membership Status': 'Platinum'},
#  {'First_Name': 'Donna',
#   'Last_Name': 'Decker',
#   'Guest_ID': 1054,
#   'Address': '5301 Parker Lodge, Hannahport, RI 29448',
#   'Phone number': '(155) 426-2218',
#   'Email': 'williamssamuel@costa-wilkerson.info',
#   'Membership Status': 'Silver'},
#  {'First_Name': 'Anthony',
#   'Last_Name': 'Davis',
#   'Guest_ID': 1055,
#   'Address': '2795 Miles Mountains, Port John, PA 11231',
#   'Phone number': '(753) 269-7311',
#   'Email': 'amy17@hotmail.com',
#   'Membership Status': 'Platinum'},
#  {'First_Name': 'Alexis',
#   'Last_Name': 'Davis',
#   'Guest_ID': 1056,
#   'Address': '91088 Ashley Drive Apt. 587, Lake Jamieshire, CO 67396',
#   'Phone number': '(565) 234-1389',
#   'Email': 'shannonlloyd@phillips.com',
#   'Membership Status': 'Standard'},
#  {'First_Name': 'Kristy',
#   'Last_Name': 'Rodgers',
#   'Guest_ID': 1057,
#   'Address': '2867 Angelica Spring, Jenniferfurt, AL 98255',
#   'Phone number': '(438) 983-6403',
#   'Email': 'petersonpamela@dennis.com',
#   'Membership Status': 'Silver'},
#  {'First_Name': 'John',
#   'Last_Name': 'Cain',
#   'Guest_ID': 1058,
#   'Address': '65180 Valerie Mountains, West Robertberg, SD 96090',
#   'Phone number': '(791) 805-5269',
#   'Email': 'bbush@hotmail.com',
#   'Membership Status': 'Platinum'},
#  {'First_Name': 'Mario',
#   'Last_Name': 'Hawkins',
#   'Guest_ID': 1059,
#   'Address': '6766 Felicia Shore Apt. 512, Ricebury, AL 99614',
#   'Phone number': '(710) 910-4300',
#   'Email': 'gmoore@harris-lee.net',
#   'Membership Status': 'Standard'},
#  {'First_Name': 'Carrie',
#   'Last_Name': 'Russo',
#   'Guest_ID': 1060,
#   'Address': '3540 Sharon Streets, Lake Yvonnefort, IA 91678',
#   'Phone number': '363-854-6785',
#   'Email': 'ugarcia@yahoo.com',
#   'Membership Status': 'Silver'},
#  {'First_Name': 'Kathleen',
#   'Last_Name': 'Flores',
#   'Guest_ID': 1061,
#   'Address': '0932 Jose Prairie Suite 423, Jerryshire, IA 65945',
#   'Phone number': '202-628-9864',
#   'Email': 'sabrinaweaver@hotmail.com',
#   'Membership Status': 'Silver'},
#  {'First_Name': 'Susan',
#   'Last_Name': 'Warren',
#   'Guest_ID': 1062,
#   'Address': '006 Megan Fort, Lake Edwardborough, NH 49417',
#   'Phone number': '997-700-8860',
#   'Email': 'amanda40@li.com',
#   'Membership Status': 'Silver'},
#  {'First_Name': 'Daniel',
#   'Last_Name': 'Davis',
#   'Guest_ID': 1063,
#   'Address': '845 Norton Common, Susanmouth, IA 91889',
#   'Phone number': '410-166-6870',
#   'Email': 'christopherbruce@mueller.com',
#   'Membership Status': 'Platinum'},
#  {'First_Name': 'Patricia',
#   'Last_Name': 'Ellison',
#   'Guest_ID': 1064,
#   'Address': '0148 Harry Vista Suite 039, Port Lori, MO 10585',
#   'Phone number': '293-968-5621',
#   'Email': 'marypeterson@hotmail.com',
#   'Membership Status': 'Platinum'},
#  {'First_Name': 'Stephanie',
#   'Last_Name': 'Sanders',
#   'Guest_ID': 1065,
#   'Address': '477 Michael Lane, Lopezshire, MS 11733',
#   'Phone number': '943-114-2626',
#   'Email': 'rward@gmail.com',
#   'Membership Status': 'Gold'},
#  {'First_Name': 'David',
#   'Last_Name': 'Lopez',
#   'Guest_ID': 1066,
#   'Address': '01581 Shields Bridge Suite 661, New Adriana, MS 22717',
#   'Phone number': '202-721-2646',
#   'Email': 'xpatton@yahoo.com',
#   'Membership Status': 'Silver'},
#  {'First_Name': 'Sheryl',
#   'Last_Name': 'Le',
#   'Guest_ID': 1067,
#   'Address': '1240 Cook River, Brockmouth, MA 56942',
#   'Phone number': '924-593-7526',
#   'Email': 'nicholas65@frederick.org',
#   'Membership Status': 'Gold'},
#  {'First_Name': 'Wendy',
#   'Last_Name': 'White',
#   'Guest_ID': 1068,
#   'Address': '737 Guerra Cliff, Chambersberg, ME 32223',
#   'Phone number': '266-179-7968',
#   'Email': 'jacqueline89@rocha.com',
#   'Membership Status': 'Standard'},
#  {'First_Name': 'Gabriel',
#   'Last_Name': 'Salazar',
#   'Guest_ID': 1069,
#   'Address': '6101 Walker Summit Apt. 756, Bartonshire, NY 20259',
#   'Phone number': '271-461-1254',
#   'Email': 'thomas77@yahoo.com',
#   'Membership Status': 'Silver'},
#  {'First_Name': 'Carlos',
#   'Last_Name': 'Williams',
#   'Guest_ID': 1070,
#   'Address': '1238 Andrea Isle, Mullenbury, MO 83044',
#   'Phone number': '266-093-7966',
#   'Email': 'jamiegoodwin@ray.com',
#   'Membership Status': 'Standard'},
#  {'First_Name': 'Michael',
#   'Last_Name': 'Gonzalez',
#   'Guest_ID': 1071,
#   'Address': '596 Matthews Keys Suite 792, Samanthashire, TX 18057',
#   'Phone number': '134-125-2866',
#   'Email': 'sreid@arias.com',
#   'Membership Status': 'Gold'},
#  {'First_Name': 'Donald',
#   'Last_Name': 'Edwards',
#   'Guest_ID': 1072,
#   'Address': '0723 Maynard Parkways, Ortizfort, VT 58677',
#   'Phone number': '219-034-0438',
#   'Email': 'armstrongjoseph@hotmail.com',
#   'Membership Status': 'Platinum'},
#  {'First_Name': 'Madeline',
#   'Last_Name': 'Richardson',
#   'Guest_ID': 1073,
#   'Address': '783 Garcia Village, West Nancy, NV 34948',
#   'Phone number': '171-339-5962',
#   'Email': 'hudsonamanda@ryan.com',
#   'Membership Status': 'Gold'},
#  {'First_Name': 'Ashley',
#   'Last_Name': 'Farley',
#   'Guest_ID': 1074,
#   'Address': '60422 Dustin Islands, Port Megan, NM 19135',
#   'Phone number': '466-711-6845',
#   'Email': 'amurphy@hotmail.com',
#   'Membership Status': 'Standard'},
#  {'First_Name': 'Christopher',
#   'Last_Name': 'Stanton',
#   'Guest_ID': 1075,
#   'Address': '86363 Adams Village Suite 589, New Melissa, MA 89964',
#   'Phone number': '202-701-2770',
#   'Email': 'penajohn@yahoo.com',
#   'Membership Status': 'Silver'},
#  {'First_Name': 'Elizabeth',
#   'Last_Name': 'Banks',
#   'Guest_ID': 1076,
#   'Address': '361 Aaron Neck Apt. 293, Smithmouth, DE 55854',
#   'Phone number': '271-361-1155',
#   'Email': 'caseyelliott@santos.com',
#   'Membership Status': 'Gold'},
#  {'First_Name': 'Samantha',
#   'Last_Name': 'Jensen',
#   'Guest_ID': 1077,
#   'Address': '12196 Richmond Island, East Joshua, IA 73035',
#   'Phone number': '994-043-8983',
#   'Email': 'pcruz@little-jones.com',
#   'Membership Status': 'Silver'},
#  {'First_Name': 'Valerie',
#   'Last_Name': 'Peck',
#   'Guest_ID': 1078,
#   'Address': '8271 Brenda Bridge Suite 300, Hunterhaven, MT 56019',
#   'Phone number': '618-892-4141',
#   'Email': 'wwillis@hotmail.com',
#   'Membership Status': 'Platinum'},
#  {'First_Name': 'Erin',
#   'Last_Name': 'Jones',
#   'Guest_ID': 1079,
#   'Address': '31617 Kyle Streets, North Alexander, UT 01988',
#   'Phone number': '758-842-5241',
#   'Email': 'lindsay48@baker.com',
#   'Membership Status': 'Platinum'},
#  {'First_Name': 'Tyler',
#   'Last_Name': 'Dixon',
#   'Guest_ID': 1080,
#   'Address': '2419 Jeremy Pass, North Micheletown, AZ 62336',
#   'Phone number': '622-086-3536',
#   'Email': 'shawrachel@gmail.com',
#   'Membership Status': 'Platinum'},
#  {'First_Name': 'Jeffrey',
#   'Last_Name': 'Black',
#   'Guest_ID': 1081,
#   'Address': '74451 Smith Flats Suite 949, South Micheal, WI 26115',
#   'Phone number': '832-060-3850',
#   'Email': 'alyssaallen@woodward-kaufman.com',
#   'Membership Status': 'Silver'},
#  {'First_Name': 'Jennifer',
#   'Last_Name': 'Davis',
#   'Guest_ID': 1082,
#   'Address': 'PSC 8657, Box 1918, APO AE 84022',
#   'Phone number': '399-062-3445',
#   'Email': 'charlesharris@hotmail.com',
#   'Membership Status': 'Gold'},
#  {'First_Name': 'Daniel',
#   'Last_Name': 'Garcia',
#   'Guest_ID': 1083,
#   'Address': '1853 Parker Greens Apt. 124, East Marymouth, CO 93713',
#   'Phone number': '568-044-2067',
#   'Email': 'murraylinda@martinez.com',
#   'Membership Status': 'Silver'},
#  {'First_Name': 'David',
#   'Last_Name': 'Colon',
#   'Guest_ID': 1084,
#   'Address': '941 Wendy Flat, Lambland, MA 16560',
#   'Phone number': '702-966-7066',
#   'Email': 'jason24@griffin-hernandez.org',
#   'Membership Status': 'Silver'},
#  {'First_Name': 'Christine',
#   'Last_Name': 'Sanchez',
#   'Guest_ID': 1085,
#   'Address': '701 Reyes Manor Apt. 838, South Kimberlystad, ND 64028',
#   'Phone number': '985-642-0593',
#   'Email': 'katie32@gmail.com',
#   'Membership Status': 'Gold'},
#  {'First_Name': 'John',
#   'Last_Name': 'Allen',
#   'Guest_ID': 1086,
#   'Address': '96522 Brittany Valley, Robintown, UT 46596',
#   'Phone number': '929-378-4270',
#   'Email': 'halljeffery@woods.com',
#   'Membership Status': 'Platinum'},
#  {'First_Name': 'Matthew',
#   'Last_Name': 'Thompson',
#   'Guest_ID': 1087,
#   'Address': '02921 Yu Landing Suite 915, Marcusburgh, NE 84290',
#   'Phone number': '528-953-9264',
#   'Email': 'whitelucas@hotmail.com',
#   'Membership Status': 'Platinum'},
#  {'First_Name': 'Jeffrey',
#   'Last_Name': 'Cunningham',
#   'Guest_ID': 1088,
#   'Address': 'USNS Rivera, FPO AE 31695',
#   'Phone number': '521-570-4331',
#   'Email': 'cruzjessica@wilkerson.biz',
#   'Membership Status': 'Gold'},
#  {'First_Name': 'Michael',
#   'Last_Name': 'Bennett',
#   'Guest_ID': 1089,
#   'Address': '71040 Green Cove, West Georgefurt, VA 10331',
#   'Phone number': '832-898-6754',
#   'Email': 'garciajamie@ortiz.net',
#   'Membership Status': 'Silver'},
#  {'First_Name': 'Joseph',
#   'Last_Name': 'Campbell',
#   'Guest_ID': 1090,
#   'Address': '9872 Michael Meadow, West Madisonfort, CT 03874',
#   'Phone number': '241-714-6774',
#   'Email': 'ylopez@lopez-williams.info',
#   'Membership Status': 'Silver'},
#  {'First_Name': 'Steven',
#   'Last_Name': 'Perez',
#   'Guest_ID': 1091,
#   'Address': '11586 Angela Ville, Cardenaschester, TX 62737',
#   'Phone number': '374-160-8989',
#   'Email': 'averyshane@stanton.com',
#   'Membership Status': 'Platinum'},
#  {'First_Name': 'Brad',
#   'Last_Name': 'Miller',
#   'Guest_ID': 1092,
#   'Address': '294 Bartlett Valley, North Paulfurt, MD 36703',
#   'Phone number': '709-986-1622',
#   'Email': 'mikayla56@reyes-washington.org',
#   'Membership Status': 'Standard'},
#  {'First_Name': 'Thomas',
#   'Last_Name': 'Jackson',
#   'Guest_ID': 1093,
#   'Address': '65307 Prince Brooks Suite 444, Garrisonville, IN 18115',
#   'Phone number': '754-691-3736',
#   'Email': 'collinswilliam@deleon.org',
#   'Membership Status': 'Standard'},
#  {'First_Name': 'Anthony',
#   'Last_Name': 'Lee',
#   'Guest_ID': 1094,
#   'Address': '07053 Richardson Mountain, Reidville, AK 32212',
#   'Phone number': '797-279-8552',
#   'Email': 'kwilliams@vincent.com',
#   'Membership Status': 'Standard'},
#  {'First_Name': 'Erica',
#   'Last_Name': 'Adams',
#   'Guest_ID': 1095,
#   'Address': '072 Carolyn Branch, West Charlene, VT 93479',
#   'Phone number': '466-574-3748',
#   'Email': 'anna99@evans-rodriguez.com',
#   'Membership Status': 'Silver'},
#  {'First_Name': 'Matthew',
#   'Last_Name': 'Hill',
#   'Guest_ID': 1096,
#   'Address': '4328 Rachel Valley Suite 520, Brightview, MT 53532',
#   'Phone number': '099-353-8758',
#   'Email': 'ruizjoyce@hotmail.com',
#   'Membership Status': 'Silver'},
#  {'First_Name': 'Lindsey',
#   'Last_Name': 'Hines',
#   'Guest_ID': 1097,
#   'Address': '135 Julie Inlet Suite 554, Stevenville, AR 83652',
#   'Phone number': '991-738-1684',
#   'Email': 'pittsedward@gmail.com',
#   'Membership Status': 'Platinum'},
#  {'First_Name': 'Matthew',
#   'Last_Name': 'Benitez',
#   'Guest_ID': 1098,
#   'Address': '52175 Lawrence Centers Apt. 743, New Kathy, WY 12040',
#   'Phone number': '966-667-6008',
#   'Email': 'stephanie58@smith.com',
#   'Membership Status': 'Standard'},
#  {'First_Name': 'Jeremy',
#   'Last_Name': 'Wiley',
#   'Guest_ID': 1099,
#   'Address': '8942 Madison Hills, Stephenhaven, NC 44781',
#   'Phone number': '257-532-6033',
#   'Email': 'richardsondebra@brooks.com',
#   'Membership Status': 'Platinum'},
#  {'First_Name': 'Kelsey',
#   'Last_Name': 'Dean',
#   'Guest_ID': 1100,
#   'Address': '100 Robert Light, New Johnnyberg, UT 90382',
#   'Phone number': '046-184-9926',
#   'Email': 'glovertyler@hotmail.com',
#   'Membership Status': 'Platinum'},
#  {'First_Name': 'James',
#   'Last_Name': 'Baker',
#   'Guest_ID': 1101,
#   'Address': '6420 Lozano Spurs, Riveratown, TN 12166',
#   'Phone number': '972-181-1437',
#   'Email': 'steven12@gmail.com',
#   'Membership Status': 'Platinum'}]

# %%
guest_collection = db.guests

# %%
guest_collection.insert_many(guests_dict)
# Out:
# InsertManyResult([ObjectId('6836260026350b88b8689c80'), ObjectId('6836260026350b88b8689c81'), ObjectId('6836260026350b88b8689c82'), ObjectId('6836260026350b88b8689c83'), ObjectId('6836260026350b88b8689c84'), ObjectId('6836260026350b88b8689c85'), ObjectId('6836260026350b88b8689c86'), ObjectId('6836260026350b88b8689c87'), ObjectId('6836260026350b88b8689c88'), ObjectId('6836260026350b88b8689c89'), ObjectId('6836260026350b88b8689c8a'), ObjectId('6836260026350b88b8689c8b'), ObjectId('6836260026350b88b8689c8c'), ObjectId('6836260026350b88b8689c8d'), ObjectId('6836260026350b88b8689c8e'), ObjectId('6836260026350b88b8689c8f'), ObjectId('6836260026350b88b8689c90'), ObjectId('6836260026350b88b8689c91'), ObjectId('6836260026350b88b8689c92'), ObjectId('6836260026350b88b8689c93'), ObjectId('6836260026350b88b8689c94'), ObjectId('6836260026350b88b8689c95'), ObjectId('6836260026350b88b8689c96'), ObjectId('6836260026350b88b8689c97'), ObjectId('6836260026350b88b8689c98'), ObjectId('6836260026350b88b8689c99'), ObjectId('6836260026350b88b8689c9a'), ObjectId('6836260026350b88b8689c9b'), ObjectId('6836260026350b88b8689c9c'), ObjectId('6836260026350b88b8689c9d'), ObjectId('6836260026350b88b8689c9e'), ObjectId('6836260026350b88b8689c9f'), ObjectId('6836260026350b88b8689ca0'), ObjectId('6836260026350b88b8689ca1'), ObjectId('6836260026350b88b8689ca2'), ObjectId('6836260026350b88b8689ca3'), ObjectId('6836260026350b88b8689ca4'), ObjectId('6836260026350b88b8689ca5'), ObjectId('6836260026350b88b8689ca6'), ObjectId('6836260026350b88b8689ca7'), ObjectId('6836260026350b88b8689ca8'), ObjectId('6836260026350b88b8689ca9'), ObjectId('6836260026350b88b8689caa'), ObjectId('6836260026350b88b8689cab'), ObjectId('6836260026350b88b8689cac'), ObjectId('6836260026350b88b8689cad'), ObjectId('6836260026350b88b8689cae'), ObjectId('6836260026350b88b8689caf'), ObjectId('6836260026350b88b8689cb0'), ObjectId('6836260026350b88b8689cb1'), ObjectId('6836260026350b88b8689cb2'), ObjectId('6836260026350b88b8689cb3'), ObjectId('6836260026350b88b8689cb4'), ObjectId('6836260026350b88b8689cb5'), ObjectId('6836260026350b88b8689cb6'), ObjectId('6836260026350b88b8689cb7'), ObjectId('6836260026350b88b8689cb8'), ObjectId('6836260026350b88b8689cb9'), ObjectId('6836260026350b88b8689cba'), ObjectId('6836260026350b88b8689cbb'), ObjectId('6836260026350b88b8689cbc'), ObjectId('6836260026350b88b8689cbd'), ObjectId('6836260026350b88b8689cbe'), ObjectId('6836260026350b88b8689cbf'), ObjectId('6836260026350b88b8689cc0'), ObjectId('6836260026350b88b8689cc1'), ObjectId('6836260026350b88b8689cc2'), ObjectId('6836260026350b88b8689cc3'), ObjectId('6836260026350b88b8689cc4'), ObjectId('6836260026350b88b8689cc5'), ObjectId('6836260026350b88b8689cc6'), ObjectId('6836260026350b88b8689cc7'), ObjectId('6836260026350b88b8689cc8'), ObjectId('6836260026350b88b8689cc9'), ObjectId('6836260026350b88b8689cca'), ObjectId('6836260026350b88b8689ccb'), ObjectId('6836260026350b88b8689ccc'), ObjectId('6836260026350b88b8689ccd'), ObjectId('6836260026350b88b8689cce'), ObjectId('6836260026350b88b8689ccf'), ObjectId('6836260026350b88b8689cd0'), ObjectId('6836260026350b88b8689cd1'), ObjectId('6836260026350b88b8689cd2'), ObjectId('6836260026350b88b8689cd3'), ObjectId('6836260026350b88b8689cd4'), ObjectId('6836260026350b88b8689cd5'), ObjectId('6836260026350b88b8689cd6'), ObjectId('6836260026350b88b8689cd7'), ObjectId('6836260026350b88b8689cd8'), ObjectId('6836260026350b88b8689cd9'), ObjectId('6836260026350b88b8689cda'), ObjectId('6836260026350b88b8689cdb'), ObjectId('6836260026350b88b8689cdc'), ObjectId('6836260026350b88b8689cdd'), ObjectId('6836260026350b88b8689cde'), ObjectId('6836260026350b88b8689cdf'), ObjectId('6836260026350b88b8689ce0'), ObjectId('6836260026350b88b8689ce1'), ObjectId('6836260026350b88b8689ce2'), ObjectId('6836260026350b88b8689ce3'), ObjectId('6836260026350b88b8689ce4')], acknowledged=True)

# %%
Payments = pd.read_excel('C:\\Users\\samue\\Downloads\\SQL project data\\Payments.xlsx')
Payments.head(3)
# Out:
#    payment_id  reservation_id payment_method payment_status  amount_in_$  \
# 0        1073               1         PayPal      Completed          220
# 1        1088               2    Credit Card      Completed          560
# 2        1021               3    Credit Card      Completed          366
#
#   payment_dates
# 0    2025-03-31
# 1    2025-02-04
# 2    2025-04-04

# %%
payments_dict = Payments.to_dict('records')
# Out:
# [{'payment_id': 1073,
#   'reservation_id': 1,
#   'payment_method': 'PayPal',
#   'payment_status': 'Completed',
#   'amount_in_$': 220,
#   'payment_dates': Timestamp('2025-03-31 00:00:00')},
#  {'payment_id': 1088,
#   'reservation_id': 2,
#   'payment_method': 'Credit Card',
#   'payment_status': 'Completed',
#   'amount_in_$': 560,
#   'payment_dates': Timestamp('2025-02-04 00:00:00')},
#  {'payment_id': 1021,
#   'reservation_id': 3,
#   'payment_method': 'Credit Card',
#   'payment_status': 'Completed',
#   'amount_in_$': 366,
#   'payment_dates': Timestamp('2025-04-04 00:00:00')},
#  {'payment_id': 1006,
#   'reservation_id': 4,
#   'payment_method': 'Cash',
#   'payment_status': 'Completed',
#   'amount_in_$': 297,
#   'payment_dates': Timestamp('2025-06-04 00:00:00')},
#  {'payment_id': 1010,
#   'reservation_id': 5,
#   'payment_method': 'Cash',
#   'payment_status': 'Pending',
#   'amount_in_$': 250,
#   'payment_dates': Timestamp('2025-08-04 00:00:00')},
#  {'payment_id': 1025,
#   'reservation_id': 6,
#   'payment_method': 'Cash',
#   'payment_status': 'Completed',
#   'amount_in_$': 388,
#   'payment_dates': Timestamp('2025-10-04 00:00:00')},
#  {'payment_id': 1095,
#   'reservation_id': 7,
#   'payment_method': 'Cash',
#   'payment_status': 'Completed',
#   'amount_in_$': 228,
#   'payment_dates': Timestamp('2025-12-04 00:00:00')},
#  {'payment_id': 1032,
#   'reservation_id': 8,
#   'payment_method': 'Debit Card',
#   'payment_status': 'Completed',
#   'amount_in_$': 125,
#   'payment_dates': Timestamp('2025-04-14 00:00:00')},
#  {'payment_id': 1079,
#   'reservation_id': 9,
#   'payment_method': 'Cash',
#   'payment_status': 'Completed',
#   'amount_in_$': 230,
#   'payment_dates': Timestamp('2025-04-16 00:00:00')},
#  {'payment_id': 1074,
#   'reservation_id': 10,
#   'payment_method': 'PayPal',
#   'payment_status': 'Completed',
#   'amount_in_$': 315,
#   'payment_dates': Timestamp('2025-04-18 00:00:00')},
#  {'payment_id': 1072,
#   'reservation_id': 11,
#   'payment_method': 'Cash',
#   'payment_status': 'Completed',
#   'amount_in_$': 366,
#   'payment_dates': Timestamp('2025-04-20 00:00:00')},
#  {'payment_id': 1033,
#   'reservation_id': 12,
#   'payment_method': 'Credit Card',
#   'payment_status': 'Completed',
#   'amount_in_$': 512,
#   'payment_dates': Timestamp('2025-04-22 00:00:00')},
#  {'payment_id': 1086,
#   'reservation_id': 13,
#   'payment_method': 'PayPal',
#   'payment_status': 'Completed',
#   'amount_in_$': 86,
#   'payment_dates': Timestamp('2025-04-24 00:00:00')},
#  {'payment_id': 1082,
#   'reservation_id': 14,
#   'payment_method': 'PayPal',
#   'payment_status': 'Completed',
#   'amount_in_$': 172,
#   'payment_dates': Timestamp('2025-04-26 00:00:00')},
#  {'payment_id': 1096,
#   'reservation_id': 15,
#   'payment_method': 'Debit Card',
#   'payment_status': 'Completed',
#   'amount_in_$': 552,
#   'payment_dates': Timestamp('2025-04-28 00:00:00')},
#  {'payment_id': 1043,
#   'reservation_id': 16,
#   'payment_method': 'Cash',
#   'payment_status': 'Pending',
#   'amount_in_$': 180,
#   'payment_dates': Timestamp('2025-04-30 00:00:00')},
#  {'payment_id': 1057,
#   'reservation_id': 17,
#   'payment_method': 'Credit Card',
#   'payment_status': 'Completed',
#   'amount_in_$': 255,
#   'payment_dates': Timestamp('2025-02-05 00:00:00')},
#  {'payment_id': 1084,
#   'reservation_id': 18,
#   'payment_method': 'Credit Card',
#   'payment_status': 'Pending',
#   'amount_in_$': 144,
#   'payment_dates': Timestamp('2025-04-05 00:00:00')},
#  {'payment_id': 1016,
#   'reservation_id': 19,
#   'payment_method': 'Debit Card',
#   'payment_status': 'Pending',
#   'amount_in_$': 113,
#   'payment_dates': Timestamp('2025-06-05 00:00:00')},
#  {'payment_id': 1058,
#   'reservation_id': 20,
#   'payment_method': 'PayPal',
#   'payment_status': 'Completed',
#   'amount_in_$': 146,
#   'payment_dates': Timestamp('2025-08-05 00:00:00')},
#  {'payment_id': 1011,
#   'reservation_id': 21,
#   'payment_method': 'PayPal',
#   'payment_status': 'Completed',
#   'amount_in_$': 134,
#   'payment_dates': Timestamp('2025-10-05 00:00:00')},
#  {'payment_id': 1049,
#   'reservation_id': 22,
#   'payment_method': 'PayPal',
#   'payment_status': 'Pending',
#   'amount_in_$': 345,
#   'payment_dates': Timestamp('2025-12-05 00:00:00')},
#  {'payment_id': 1097,
#   'reservation_id': 23,
#   'payment_method': 'Debit Card',
#   'payment_status': 'Completed',
#   'amount_in_$': 435,
#   'payment_dates': Timestamp('2025-05-14 00:00:00')},
#  {'payment_id': 1092,
#   'reservation_id': 24,
#   'payment_method': 'Debit Card',
#   'payment_status': 'Pending',
#   'amount_in_$': 103,
#   'payment_dates': Timestamp('2025-05-16 00:00:00')},
#  {'payment_id': 1001,
#   'reservation_id': 25,
#   'payment_method': 'Cash',
#   'payment_status': 'Failed',
#   'amount_in_$': 200,
#   'payment_dates': Timestamp('2025-05-18 00:00:00')},
#  {'payment_id': 1007,
#   'reservation_id': 26,
#   'payment_method': 'Debit Card',
#   'payment_status': 'Completed',
#   'amount_in_$': 230,
#   'payment_dates': Timestamp('2025-05-20 00:00:00')},
#  {'payment_id': 1077,
#   'reservation_id': 27,
#   'payment_method': 'Credit Card',
#   'payment_status': 'Completed',
#   'amount_in_$': 224,
#   'payment_dates': Timestamp('2025-05-22 00:00:00')},
#  {'payment_id': 1003,
#   'reservation_id': 28,
#   'payment_method': 'PayPal',
#   'payment_status': 'Completed',
#   'amount_in_$': 384,
#   'payment_dates': Timestamp('2025-05-24 00:00:00')},
#  {'payment_id': 1015,
#   'reservation_id': 29,
#   'payment_method': 'Debit Card',
#   'payment_status': 'Completed',
#   'amount_in_$': 282,
#   'payment_dates': Timestamp('2025-05-26 00:00:00')},
#  {'payment_id': 1035,
#   'reservation_id': 30,
#   'payment_method': 'PayPal',
#   'payment_status': 'Completed',
#   'amount_in_$': 460,
#   'payment_dates': Timestamp('2025-05-28 00:00:00')},
#  {'payment_id': 1052,
#   'reservation_id': 31,
#   'payment_method': 'Credit Card',
#   'payment_status': 'Pending',
#   'amount_in_$': 330,
#   'payment_dates': Timestamp('2025-05-30 00:00:00')},
#  {'payment_id': 1012,
#   'reservation_id': 32,
#   'payment_method': 'Credit Card',
#   'payment_status': 'Completed',
#   'amount_in_$': 282,
#   'payment_dates': Timestamp('2025-01-06 00:00:00')},
#  {'payment_id': 1009,
#   'reservation_id': 33,
#   'payment_method': 'Credit Card',
#   'payment_status': 'Completed',
#   'amount_in_$': 82,
#   'payment_dates': Timestamp('2025-03-06 00:00:00')},
#  {'payment_id': 1017,
#   'reservation_id': 34,
#   'payment_method': 'Cash',
#   'payment_status': 'Pending',
#   'amount_in_$': 190,
#   'payment_dates': Timestamp('2025-05-06 00:00:00')},
#  {'payment_id': 1038,
#   'reservation_id': 35,
#   'payment_method': 'PayPal',
#   'payment_status': 'Completed',
#   'amount_in_$': 399,
#   'payment_dates': Timestamp('2025-07-06 00:00:00')},
#  {'payment_id': 1091,
#   'reservation_id': 36,
#   'payment_method': 'PayPal',
#   'payment_status': 'Completed',
#   'amount_in_$': 351,
#   'payment_dates': Timestamp('2025-09-06 00:00:00')},
#  {'payment_id': 1020,
#   'reservation_id': 37,
#   'payment_method': 'Credit Card',
#   'payment_status': 'Pending',
#   'amount_in_$': 420,
#   'payment_dates': Timestamp('2025-11-06 00:00:00')},
#  {'payment_id': 1060,
#   'reservation_id': 38,
#   'payment_method': 'Debit Card',
#   'payment_status': 'Completed',
#   'amount_in_$': 200,
#   'payment_dates': Timestamp('2025-06-13 00:00:00')},
#  {'payment_id': 1071,
#   'reservation_id': 39,
#   'payment_method': 'Credit Card',
#   'payment_status': 'Completed',
#   'amount_in_$': 580,
#   'payment_dates': Timestamp('2025-06-15 00:00:00')},
#  {'payment_id': 1002,
#   'reservation_id': 40,
#   'payment_method': 'Debit Card',
#   'payment_status': 'Completed',
#   'amount_in_$': 432,
#   'payment_dates': Timestamp('2025-06-17 00:00:00')},
#  {'payment_id': 1000,
#   'reservation_id': 41,
#   'payment_method': 'Debit Card',
#   'payment_status': 'Completed',
#   'amount_in_$': 124,
#   'payment_dates': Timestamp('2025-06-19 00:00:00')},
#  {'payment_id': 1005,
#   'reservation_id': 42,
#   'payment_method': 'PayPal',
#   'payment_status': 'Completed',
#   'amount_in_$': 328,
#   'payment_dates': Timestamp('2025-06-21 00:00:00')},
#  {'payment_id': 1018,
#   'reservation_id': 43,
#   'payment_method': 'PayPal',
#   'payment_status': 'Completed',
#   'amount_in_$': 141,
#   'payment_dates': Timestamp('2025-06-23 00:00:00')},
#  {'payment_id': 1046,
#   'reservation_id': 44,
#   'payment_method': 'Cash',
#   'payment_status': 'Completed',
#   'amount_in_$': 296,
#   'payment_dates': Timestamp('2025-06-25 00:00:00')},
#  {'payment_id': 1064,
#   'reservation_id': 45,
#   'payment_method': 'PayPal',
#   'payment_status': 'Completed',
#   'amount_in_$': 160,
#   'payment_dates': Timestamp('2025-06-27 00:00:00')},
#  {'payment_id': 1004,
#   'reservation_id': 46,
#   'payment_method': 'PayPal',
#   'payment_status': 'Pending',
#   'amount_in_$': 282,
#   'payment_dates': Timestamp('2025-06-29 00:00:00')},
#  {'payment_id': 1081,
#   'reservation_id': 47,
#   'payment_method': 'PayPal',
#   'payment_status': 'Completed',
#   'amount_in_$': 400,
#   'payment_dates': Timestamp('2025-01-07 00:00:00')},
#  {'payment_id': 1022,
#   'reservation_id': 48,
#   'payment_method': 'Cash',
#   'payment_status': 'Completed',
#   'amount_in_$': 282,
#   'payment_dates': Timestamp('2025-03-07 00:00:00')},
#  {'payment_id': 1061,
#   'reservation_id': 49,
#   'payment_method': 'Credit Card',
#   'payment_status': 'Completed',
#   'amount_in_$': 548,
#   'payment_dates': Timestamp('2025-05-07 00:00:00')},
#  {'payment_id': 1067,
#   'reservation_id': 50,
#   'payment_method': 'Cash',
#   'payment_status': 'Completed',
#   'amount_in_$': 214,
#   'payment_dates': Timestamp('2025-07-07 00:00:00')},
#  {'payment_id': 1048,
#   'reservation_id': 51,
#   'payment_method': 'Debit Card',
#   'payment_status': 'Completed',
#   'amount_in_$': 352,
#   'payment_dates': Timestamp('2025-09-07 00:00:00')},
#  {'payment_id': 1039,
#   'reservation_id': 52,
#   'payment_method': 'Debit Card',
#   'payment_status': 'Completed',
#   'amount_in_$': 536,
#   'payment_dates': Timestamp('2025-11-07 00:00:00')},
#  {'payment_id': 1042,
#   'reservation_id': 53,
#   'payment_method': 'PayPal',
#   'payment_status': 'Failed',
#   'amount_in_$': 332,
#   'payment_dates': Timestamp('2025-07-13 00:00:00')},
#  {'payment_id': 1099,
#   'reservation_id': 54,
#   'payment_method': 'PayPal',
#   'payment_status': 'Completed',
#   'amount_in_$': 291,
#   'payment_dates': Timestamp('2025-07-15 00:00:00')},
#  {'payment_id': 1041,
#   'reservation_id': 55,
#   'payment_method': 'PayPal',
#   'payment_status': 'Failed',
#   'amount_in_$': 440,
#   'payment_dates': Timestamp('2025-07-17 00:00:00')},
#  {'payment_id': 1040,
#   'reservation_id': 56,
#   'payment_method': 'Debit Card',
#   'payment_status': 'Completed',
#   'amount_in_$': 145,
#   'payment_dates': Timestamp('2025-07-19 00:00:00')},
#  {'payment_id': 1013,
#   'reservation_id': 57,
#   'payment_method': 'Cash',
#   'payment_status': 'Pending',
#   'amount_in_$': 492,
#   'payment_dates': Timestamp('2025-07-21 00:00:00')},
#  {'payment_id': 1019,
#   'reservation_id': 58,
#   'payment_method': 'Cash',
#   'payment_status': 'Completed',
#   'amount_in_$': 315,
#   'payment_dates': Timestamp('2025-07-23 00:00:00')},
#  {'payment_id': 1029,
#   'reservation_id': 59,
#   'payment_method': 'Credit Card',
#   'payment_status': 'Completed',
#   'amount_in_$': 387,
#   'payment_dates': Timestamp('2025-07-25 00:00:00')},
#  {'payment_id': 1059,
#   'reservation_id': 60,
#   'payment_method': 'PayPal',
#   'payment_status': 'Completed',
#   'amount_in_$': 286,
#   'payment_dates': Timestamp('2025-07-27 00:00:00')},
#  {'payment_id': 1028,
#   'reservation_id': 61,
#   'payment_method': 'Debit Card',
#   'payment_status': 'Pending',
#   'amount_in_$': 110,
#   'payment_dates': Timestamp('2025-07-29 00:00:00')},
#  {'payment_id': 1063,
#   'reservation_id': 62,
#   'payment_method': 'Credit Card',
#   'payment_status': 'Completed',
#   'amount_in_$': 291,
#   'payment_dates': Timestamp('2025-07-31 00:00:00')},
#  {'payment_id': 1008,
#   'reservation_id': 63,
#   'payment_method': 'Cash',
#   'payment_status': 'Pending',
#   'amount_in_$': 240,
#   'payment_dates': Timestamp('2025-02-08 00:00:00')},
#  {'payment_id': 1050,
#   'reservation_id': 64,
#   'payment_method': 'Credit Card',
#   'payment_status': 'Completed',
#   'amount_in_$': 375,
#   'payment_dates': Timestamp('2025-04-08 00:00:00')},
#  {'payment_id': 1078,
#   'reservation_id': 65,
#   'payment_method': 'PayPal',
#   'payment_status': 'Completed',
#   'amount_in_$': 146,
#   'payment_dates': Timestamp('2025-06-08 00:00:00')},
#  {'payment_id': 1054,
#   'reservation_id': 66,
#   'payment_method': 'Credit Card',
#   'payment_status': 'Failed',
#   'amount_in_$': 580,
#   'payment_dates': Timestamp('2025-08-08 00:00:00')},
#  {'payment_id': 1070,
#   'reservation_id': 67,
#   'payment_method': 'Cash',
#   'payment_status': 'Pending',
#   'amount_in_$': 417,
#   'payment_dates': Timestamp('2025-10-08 00:00:00')},
#  {'payment_id': 1014,
#   'reservation_id': 68,
#   'payment_method': 'Debit Card',
#   'payment_status': 'Completed',
#   'amount_in_$': 372,
#   'payment_dates': Timestamp('2025-12-08 00:00:00')},
#  {'payment_id': 1051,
#   'reservation_id': 69,
#   'payment_method': 'Credit Card',
#   'payment_status': 'Completed',
#   'amount_in_$': 369,
#   'payment_dates': Timestamp('2025-08-14 00:00:00')},
#  {'payment_id': 1047,
#   'reservation_id': 70,
#   'payment_method': 'Credit Card',
#   'payment_status': 'Completed',
#   'amount_in_$': 464,
#   'payment_dates': Timestamp('2025-08-16 00:00:00')},
#  {'payment_id': 1069,
#   'reservation_id': 71,
#   'payment_method': 'Cash',
#   'payment_status': 'Completed',
#   'amount_in_$': 99,
#   'payment_dates': Timestamp('2025-08-18 00:00:00')},
#  {'payment_id': 1027,
#   'reservation_id': 72,
#   'payment_method': 'Cash',
#   'payment_status': 'Completed',
#   'amount_in_$': 321,
#   'payment_dates': Timestamp('2025-08-20 00:00:00')},
#  {'payment_id': 1066,
#   'reservation_id': 73,
#   'payment_method': 'PayPal',
#   'payment_status': 'Completed',
#   'amount_in_$': 381,
#   'payment_dates': Timestamp('2025-08-22 00:00:00')},
#  {'payment_id': 1075,
#   'reservation_id': 74,
#   'payment_method': 'Debit Card',
#   'payment_status': 'Completed',
#   'amount_in_$': 488,
#   'payment_dates': Timestamp('2025-08-24 00:00:00')},
#  {'payment_id': 1085,
#   'reservation_id': 75,
#   'payment_method': 'Cash',
#   'payment_status': 'Completed',
#   'amount_in_$': 282,
#   'payment_dates': Timestamp('2025-08-26 00:00:00')},
#  {'payment_id': 1089,
#   'reservation_id': 76,
#   'payment_method': 'Debit Card',
#   'payment_status': 'Completed',
#   'amount_in_$': 404,
#   'payment_dates': Timestamp('2025-08-28 00:00:00')},
#  {'payment_id': 1056,
#   'reservation_id': 77,
#   'payment_method': 'Debit Card',
#   'payment_status': 'Failed',
#   'amount_in_$': 580,
#   'payment_dates': Timestamp('2025-08-30 00:00:00')},
#  {'payment_id': 1083,
#   'reservation_id': 78,
#   'payment_method': 'Cash',
#   'payment_status': 'Completed',
#   'amount_in_$': 488,
#   'payment_dates': Timestamp('2025-01-09 00:00:00')},
#  {'payment_id': 1055,
#   'reservation_id': 79,
#   'payment_method': 'PayPal',
#   'payment_status': 'Completed',
#   'amount_in_$': 508,
#   'payment_dates': Timestamp('2025-03-09 00:00:00')},
#  {'payment_id': 1098,
#   'reservation_id': 80,
#   'payment_method': 'Credit Card',
#   'payment_status': 'Completed',
#   'amount_in_$': 168,
#   'payment_dates': Timestamp('2025-05-09 00:00:00')},
#  {'payment_id': 1036,
#   'reservation_id': 81,
#   'payment_method': 'Debit Card',
#   'payment_status': 'Completed',
#   'amount_in_$': 192,
#   'payment_dates': Timestamp('2025-07-09 00:00:00')},
#  {'payment_id': 1094,
#   'reservation_id': 82,
#   'payment_method': 'Debit Card',
#   'payment_status': 'Completed',
#   'amount_in_$': 148,
#   'payment_dates': Timestamp('2025-09-09 00:00:00')},
#  {'payment_id': 1023,
#   'reservation_id': 83,
#   'payment_method': 'Credit Card',
#   'payment_status': 'Completed',
#   'amount_in_$': 166,
#   'payment_dates': Timestamp('2025-11-09 00:00:00')},
#  {'payment_id': 1076,
#   'reservation_id': 84,
#   'payment_method': 'Cash',
#   'payment_status': 'Completed',
#   'amount_in_$': 224,
#   'payment_dates': Timestamp('2025-09-13 00:00:00')},
#  {'payment_id': 1024,
#   'reservation_id': 85,
#   'payment_method': 'PayPal',
#   'payment_status': 'Completed',
#   'amount_in_$': 504,
#   'payment_dates': Timestamp('2025-09-15 00:00:00')},
#  {'payment_id': 1053,
#   'reservation_id': 86,
#   'payment_method': 'Debit Card',
#   'payment_status': 'Completed',
#   'amount_in_$': 294,
#   'payment_dates': Timestamp('2025-09-17 00:00:00')},
#  {'payment_id': 1031,
#   'reservation_id': 87,
#   'payment_method': 'Cash',
#   'payment_status': 'Completed',
#   'amount_in_$': 296,
#   'payment_dates': Timestamp('2025-09-19 00:00:00')},
#  {'payment_id': 1093,
#   'reservation_id': 88,
#   'payment_method': 'Cash',
#   'payment_status': 'Completed',
#   'amount_in_$': 190,
#   'payment_dates': Timestamp('2025-09-21 00:00:00')},
#  {'payment_id': 1062,
#   'reservation_id': 89,
#   'payment_method': 'PayPal',
#   'payment_status': 'Completed',
#   'amount_in_$': 390,
#   'payment_dates': Timestamp('2025-09-23 00:00:00')},
#  {'payment_id': 1087,
#   'reservation_id': 90,
#   'payment_method': 'Debit Card',
#   'payment_status': 'Completed',
#   'amount_in_$': 480,
#   'payment_dates': Timestamp('2025-09-25 00:00:00')},
#  {'payment_id': 1037,
#   'reservation_id': 91,
#   'payment_method': 'Credit Card',
#   'payment_status': 'Completed',
#   'amount_in_$': 435,
#   'payment_dates': Timestamp('2025-09-27 00:00:00')},
#  {'payment_id': 1045,
#   'reservation_id': 92,
#   'payment_method': 'Cash',
#   'payment_status': 'Completed',
#   'amount_in_$': 387,
#   'payment_dates': Timestamp('2025-09-29 00:00:00')},
#  {'payment_id': 1068,
#   'reservation_id': 93,
#   'payment_method': 'Cash',
#   'payment_status': 'Completed',
#   'amount_in_$': 140,
#   'payment_dates': Timestamp('2025-01-10 00:00:00')},
#  {'payment_id': 1100,
#   'reservation_id': 94,
#   'payment_method': 'Cash',
#   'payment_status': 'Completed',
#   'amount_in_$': 324,
#   'payment_dates': Timestamp('2025-03-10 00:00:00')},
#  {'payment_id': 1034,
#   'reservation_id': 95,
#   'payment_method': 'PayPal',
#   'payment_status': 'Completed',
#   'amount_in_$': 321,
#   'payment_dates': Timestamp('2025-05-10 00:00:00')},
#  {'payment_id': 1065,
#   'reservation_id': 96,
#   'payment_method': 'PayPal',
#   'payment_status': 'Completed',
#   'amount_in_$': 296,
#   'payment_dates': Timestamp('2025-07-10 00:00:00')},
#  {'payment_id': 1090,
#   'reservation_id': 97,
#   'payment_method': 'PayPal',
#   'payment_status': 'Completed',
#   'amount_in_$': 252,
#   'payment_dates': Timestamp('2025-09-10 00:00:00')},
#  {'payment_id': 1101,
#   'reservation_id': 98,
#   'payment_method': 'Cash',
#   'payment_status': 'Completed',
#   'amount_in_$': 137,
#   'payment_dates': Timestamp('2025-11-10 00:00:00')},
#  {'payment_id': 1030,
#   'reservation_id': 99,
#   'payment_method': 'Debit Card',
#   'payment_status': 'Completed',
#   'amount_in_$': 246,
#   'payment_dates': Timestamp('2025-10-13 00:00:00')},
#  {'payment_id': 1080,
#   'reservation_id': 100,
#   'payment_method': 'PayPal',
#   'payment_status': 'Completed',
#   'amount_in_$': 492,
#   'payment_dates': Timestamp('2025-10-15 00:00:00')},
#  {'payment_id': 1044,
#   'reservation_id': 101,
#   'payment_method': 'Credit Card',
#   'payment_status': 'Completed',
#   'amount_in_$': 255,
#   'payment_dates': Timestamp('2025-10-17 00:00:00')},
#  {'payment_id': 1026,
#   'reservation_id': 102,
#   'payment_method': 'Cash',
#   'payment_status': 'Completed',
#   'amount_in_$': 102,
#   'payment_dates': Timestamp('2025-10-19 00:00:00')}]

# %%
payment_collection = db.Payments

# %%
payment_collection.insert_many(payments_dict)
# Out:
# InsertManyResult([ObjectId('68370b5026350b88b8689ce5'), ObjectId('68370b5026350b88b8689ce6'), ObjectId('68370b5026350b88b8689ce7'), ObjectId('68370b5026350b88b8689ce8'), ObjectId('68370b5026350b88b8689ce9'), ObjectId('68370b5026350b88b8689cea'), ObjectId('68370b5026350b88b8689ceb'), ObjectId('68370b5026350b88b8689cec'), ObjectId('68370b5026350b88b8689ced'), ObjectId('68370b5026350b88b8689cee'), ObjectId('68370b5026350b88b8689cef'), ObjectId('68370b5026350b88b8689cf0'), ObjectId('68370b5026350b88b8689cf1'), ObjectId('68370b5026350b88b8689cf2'), ObjectId('68370b5026350b88b8689cf3'), ObjectId('68370b5026350b88b8689cf4'), ObjectId('68370b5026350b88b8689cf5'), ObjectId('68370b5026350b88b8689cf6'), ObjectId('68370b5026350b88b8689cf7'), ObjectId('68370b5026350b88b8689cf8'), ObjectId('68370b5026350b88b8689cf9'), ObjectId('68370b5026350b88b8689cfa'), ObjectId('68370b5026350b88b8689cfb'), ObjectId('68370b5026350b88b8689cfc'), ObjectId('68370b5026350b88b8689cfd'), ObjectId('68370b5026350b88b8689cfe'), ObjectId('68370b5026350b88b8689cff'), ObjectId('68370b5026350b88b8689d00'), ObjectId('68370b5026350b88b8689d01'), ObjectId('68370b5026350b88b8689d02'), ObjectId('68370b5026350b88b8689d03'), ObjectId('68370b5026350b88b8689d04'), ObjectId('68370b5026350b88b8689d05'), ObjectId('68370b5026350b88b8689d06'), ObjectId('68370b5026350b88b8689d07'), ObjectId('68370b5026350b88b8689d08'), ObjectId('68370b5026350b88b8689d09'), ObjectId('68370b5026350b88b8689d0a'), ObjectId('68370b5026350b88b8689d0b'), ObjectId('68370b5026350b88b8689d0c'), ObjectId('68370b5026350b88b8689d0d'), ObjectId('68370b5026350b88b8689d0e'), ObjectId('68370b5026350b88b8689d0f'), ObjectId('68370b5026350b88b8689d10'), ObjectId('68370b5026350b88b8689d11'), ObjectId('68370b5026350b88b8689d12'), ObjectId('68370b5026350b88b8689d13'), ObjectId('68370b5026350b88b8689d14'), ObjectId('68370b5026350b88b8689d15'), ObjectId('68370b5026350b88b8689d16'), ObjectId('68370b5026350b88b8689d17'), ObjectId('68370b5026350b88b8689d18'), ObjectId('68370b5026350b88b8689d19'), ObjectId('68370b5026350b88b8689d1a'), ObjectId('68370b5026350b88b8689d1b'), ObjectId('68370b5026350b88b8689d1c'), ObjectId('68370b5026350b88b8689d1d'), ObjectId('68370b5026350b88b8689d1e'), ObjectId('68370b5026350b88b8689d1f'), ObjectId('68370b5026350b88b8689d20'), ObjectId('68370b5026350b88b8689d21'), ObjectId('68370b5026350b88b8689d22'), ObjectId('68370b5026350b88b8689d23'), ObjectId('68370b5026350b88b8689d24'), ObjectId('68370b5026350b88b8689d25'), ObjectId('68370b5026350b88b8689d26'), ObjectId('68370b5026350b88b8689d27'), ObjectId('68370b5026350b88b8689d28'), ObjectId('68370b5026350b88b8689d29'), ObjectId('68370b5026350b88b8689d2a'), ObjectId('68370b5026350b88b8689d2b'), ObjectId('68370b5026350b88b8689d2c'), ObjectId('68370b5026350b88b8689d2d'), ObjectId('68370b5026350b88b8689d2e'), ObjectId('68370b5026350b88b8689d2f'), ObjectId('68370b5026350b88b8689d30'), ObjectId('68370b5026350b88b8689d31'), ObjectId('68370b5026350b88b8689d32'), ObjectId('68370b5026350b88b8689d33'), ObjectId('68370b5026350b88b8689d34'), ObjectId('68370b5026350b88b8689d35'), ObjectId('68370b5026350b88b8689d36'), ObjectId('68370b5026350b88b8689d37'), ObjectId('68370b5026350b88b8689d38'), ObjectId('68370b5026350b88b8689d39'), ObjectId('68370b5026350b88b8689d3a'), ObjectId('68370b5026350b88b8689d3b'), ObjectId('68370b5026350b88b8689d3c'), ObjectId('68370b5026350b88b8689d3d'), ObjectId('68370b5026350b88b8689d3e'), ObjectId('68370b5026350b88b8689d3f'), ObjectId('68370b5026350b88b8689d40'), ObjectId('68370b5026350b88b8689d41'), ObjectId('68370b5026350b88b8689d42'), ObjectId('68370b5026350b88b8689d43'), ObjectId('68370b5026350b88b8689d44'), ObjectId('68370b5026350b88b8689d45'), ObjectId('68370b5026350b88b8689d46'), ObjectId('68370b5026350b88b8689d47'), ObjectId('68370b5026350b88b8689d48'), ObjectId('68370b5026350b88b8689d49'), ObjectId('68370b5026350b88b8689d4a')], acknowledged=True)

# %% [markdown]
# # Creating a Nested Reservations Record

# %%
reservations_guests = Reservations.merge(
    guests, how="left", left_on="guest_id", right_on="Guest_ID"
)

# %%
reservations_guests_rooms = reservations_guests.merge(
    Rooms, how="left", on="room_id"
)

# %%
nested_df = reservations_guests_rooms.merge(
    Payments, how="left", on="reservation_id"
)

# %%
def create_nested_record(row):
    return {
        "reservation_id": row["reservation_id"],
        "check_in_date": str(row["check_in_date"]),
        "check_out_date": str(row["check_out_date"]),
        "is_occupied": row["is_occupied"],
        "cleanliness_state": row["cleanliness_state"],
        "guest": {
            "guest_id": row["Guest_ID"],
            "first_name": row["First_Name"],
            "last_name": row["Last_Name"],
            "email": row["Email"],
            "phone": row["Phone number"],
            "membership_status": row["Membership Status"],
            "address": row["Address"]
        },
        "room": {
            "room_id": row["room_id"],
            "number": row["number"],
            "view_type": row["view_type"],
            "capacity": row["capacity"],
            "room_type": row["room_type"],
            "availability": row["availability"],
            "last_maintenance_date": str(row["last_maintenance_date"]),
            "accessibility_accomodation": row["accessibility_accomodation"]
        },
        "payment": {
            "payment_id": row["payment_id"],
            "payment_method": row["payment_method"],
            "payment_status": row["payment_status"],
            "amount": row["amount_in_$"],
            "payment_date": str(row["payment_dates"])
        }
    }

# %%
nested_records = nested_df.apply(create_nested_record, axis=1).tolist()

# %%
nested_reservations = db.Nested_data

# %%
nested_reservations.insert_many(nested_records)
# Out:
# InsertManyResult([ObjectId('68373b1426350b88b8689d4b'), ObjectId('68373b1426350b88b8689d4c'), ObjectId('68373b1426350b88b8689d4d'), ObjectId('68373b1426350b88b8689d4e'), ObjectId('68373b1426350b88b8689d4f'), ObjectId('68373b1426350b88b8689d50'), ObjectId('68373b1426350b88b8689d51'), ObjectId('68373b1426350b88b8689d52'), ObjectId('68373b1426350b88b8689d53'), ObjectId('68373b1426350b88b8689d54'), ObjectId('68373b1426350b88b8689d55'), ObjectId('68373b1426350b88b8689d56'), ObjectId('68373b1426350b88b8689d57'), ObjectId('68373b1426350b88b8689d58'), ObjectId('68373b1426350b88b8689d59'), ObjectId('68373b1426350b88b8689d5a'), ObjectId('68373b1426350b88b8689d5b'), ObjectId('68373b1426350b88b8689d5c'), ObjectId('68373b1426350b88b8689d5d'), ObjectId('68373b1426350b88b8689d5e'), ObjectId('68373b1426350b88b8689d5f'), ObjectId('68373b1426350b88b8689d60'), ObjectId('68373b1426350b88b8689d61'), ObjectId('68373b1426350b88b8689d62'), ObjectId('68373b1426350b88b8689d63'), ObjectId('68373b1426350b88b8689d64'), ObjectId('68373b1426350b88b8689d65'), ObjectId('68373b1426350b88b8689d66'), ObjectId('68373b1426350b88b8689d67'), ObjectId('68373b1426350b88b8689d68'), ObjectId('68373b1426350b88b8689d69'), ObjectId('68373b1426350b88b8689d6a'), ObjectId('68373b1426350b88b8689d6b'), ObjectId('68373b1426350b88b8689d6c'), ObjectId('68373b1426350b88b8689d6d'), ObjectId('68373b1426350b88b8689d6e'), ObjectId('68373b1426350b88b8689d6f'), ObjectId('68373b1426350b88b8689d70'), ObjectId('68373b1426350b88b8689d71'), ObjectId('68373b1426350b88b8689d72'), ObjectId('68373b1426350b88b8689d73'), ObjectId('68373b1426350b88b8689d74'), ObjectId('68373b1426350b88b8689d75'), ObjectId('68373b1426350b88b8689d76'), ObjectId('68373b1426350b88b8689d77'), ObjectId('68373b1426350b88b8689d78'), ObjectId('68373b1426350b88b8689d79'), ObjectId('68373b1426350b88b8689d7a'), ObjectId('68373b1426350b88b8689d7b'), ObjectId('68373b1426350b88b8689d7c'), ObjectId('68373b1426350b88b8689d7d'), ObjectId('68373b1426350b88b8689d7e'), ObjectId('68373b1426350b88b8689d7f'), ObjectId('68373b1426350b88b8689d80'), ObjectId('68373b1426350b88b8689d81'), ObjectId('68373b1426350b88b8689d82'), ObjectId('68373b1426350b88b8689d83'), ObjectId('68373b1426350b88b8689d84'), ObjectId('68373b1426350b88b8689d85'), ObjectId('68373b1426350b88b8689d86'), ObjectId('68373b1426350b88b8689d87'), ObjectId('68373b1426350b88b8689d88'), ObjectId('68373b1426350b88b8689d89'), ObjectId('68373b1426350b88b8689d8a'), ObjectId('68373b1426350b88b8689d8b'), ObjectId('68373b1426350b88b8689d8c'), ObjectId('68373b1426350b88b8689d8d'), ObjectId('68373b1426350b88b8689d8e'), ObjectId('68373b1426350b88b8689d8f'), ObjectId('68373b1426350b88b8689d90'), ObjectId('68373b1426350b88b8689d91'), ObjectId('68373b1426350b88b8689d92'), ObjectId('68373b1426350b88b8689d93'), ObjectId('68373b1426350b88b8689d94'), ObjectId('68373b1426350b88b8689d95'), ObjectId('68373b1426350b88b8689d96'), ObjectId('68373b1426350b88b8689d97'), ObjectId('68373b1426350b88b8689d98'), ObjectId('68373b1426350b88b8689d99'), ObjectId('68373b1426350b88b8689d9a'), ObjectId('68373b1426350b88b8689d9b'), ObjectId('68373b1426350b88b8689d9c'), ObjectId('68373b1426350b88b8689d9d'), ObjectId('68373b1426350b88b8689d9e'), ObjectId('68373b1426350b88b8689d9f'), ObjectId('68373b1426350b88b8689da0'), ObjectId('68373b1426350b88b8689da1'), ObjectId('68373b1426350b88b8689da2'), ObjectId('68373b1426350b88b8689da3'), ObjectId('68373b1426350b88b8689da4'), ObjectId('68373b1426350b88b8689da5'), ObjectId('68373b1426350b88b8689da6'), ObjectId('68373b1426350b88b8689da7'), ObjectId('68373b1426350b88b8689da8'), ObjectId('68373b1426350b88b8689da9'), ObjectId('68373b1426350b88b8689daa'), ObjectId('68373b1426350b88b8689dab'), ObjectId('68373b1426350b88b8689dac'), ObjectId('68373b1426350b88b8689dad'), ObjectId('68373b1426350b88b8689dae'), ObjectId('68373b1426350b88b8689daf'), ObjectId('68373b1426350b88b8689db0')], acknowledged=True)
